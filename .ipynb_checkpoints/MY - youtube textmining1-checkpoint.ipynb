# 25        2개
# 26        1개
# 27        8개
# 28        4개
# 29        1개
# ..       ...
# 110       0개
# 111       0개
# 112       0개
# 113       0개
# 114       0개
# 115       0개
# 116       0개
# 117       0개
# 118       0개
# 119       0개
# 120       0개
# 121       0개
# 122       0개
# 123       0개
# 124       0개
# 125       0개
# 126       0개
# 127       0개
# 128       0개
# 129       0개
# 130       0개
# 131       0개
# 132       0개
# 133       0개
# 134       0개
# 135       0개
# 136       0개
# 137       0개
# 138       0개
# 139       0개
#
# [140 rows x 3 columns]

# %%
#이모티콘 제거
emoji_pattern = re.compile("["
        u"\U0001F600-\U0001F64F"  # emoticons
        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
        u"\U0001F680-\U0001F6FF"  # transport & map symbols
        u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           "]+", flags=re.UNICODE)

#분석에 어긋나는 불용어구 제외 (특수문자, 의성어)
han = re.compile(r'[ㄱ-ㅎㅏ-ㅣ!?~,".\n\r#\ufeff\u200d]')

# %%
comment_list = []
for i in range(len(comment_data)):
    comment_list.append(comment_data['comment'].iloc[i])

# %%
comment_result = []

for i in comment_list:
    tokens = re.sub(emoji_pattern,"",i)
    tokens = re.sub(han,"",tokens)
    comment_result.append(tokens)

comment_result = pd.DataFrame(comment_result, columns=["comment"])

# %%
comment_result
# Out:
#                                                comment
# 0                                자라 슈즈가 이렇게 예쁜거투성이였다구요
# 1    안녕하세요 이번 영상 편집자 셩입니다정보 오류가 몇군데 있어 댓글 남깁니다자딕앤볼테...
# 2    원했던 컨텐츠였는데이렇게 딱 올려주다니 역시 역시 뭘 좀 아시는 센스 사배님 영상 ...
# 3    omg amazing lookbook all the outfits are just ...
# 4    메이크업아티스트 사배200만 유투버 사배🤘아이돌 가수 사배연예인 사배🤹♀️모델 사배...
# 5                                      이 영상을 자라가 좋아합니다
# 6    언니메이크업부터 스타일까지 진짜 미쳣어요 너무 좋아 반짝빤짝한 옷 악세사리 좋아하는...
# 7    사배언니정말사랑해요 언니옛날부터쭉봐왔여요 아프리카티비할때 해달라던 컨텐츠 두개씩이나...
# 8                 미모에 몸매에 기럭지는 또 무슨 일이예요 언니 저랑 결혼해줘요잉잉
# 9                  The Korean womans are so beautiful
# 10   옷들이 다 사배님이라서 소화가능한 옷인거같아요 완전 잘 어울려요 ❤️❤️❤️❤️ 옷...
# 11                                         편집자님 능력 대박적
# 12            진짜 포즈 취하는거 천상 유어녜인  발끝에서도 나오는 언니의 끼 넘모좋앙
# 13                       세번째 룩 메이크업 너무 예뻐욧 너무 제 취향이에요❤
# 14                         요새언니 영상만봐도 이렇게 힐링될수있다니사랑해욤❣
# 15   사배언니 헤어스타일링 방법도 궁금해요특히 앞머리 부분 볼륨을 어떻게 세우시고 유지하지나용
# 16   사배언니 크진않지만 정말 신경쓰이는 고민이 생겼어요곧 학교에서 체육대회를하는데 키라...
# 17                     마지막 룩북이진짜 조녜 찰떡이네요 청순청순 화이트 원피스
# 18                                    자라가 신발 맛집인줄은 몰랐넹
# 19                                          언니 미모 실화야
# 20                          아 진짜 모델이에요🤭너무 이뻐요 으아악 사랑해요
# 21   I'm jealous because of your perfect body and f...
# 22                             오늘도 쏘골져스 앤 판타스틱한 우리 언니✨
# 23                         시험기간에도 사배님 영상은 보구가여 정말 예쁘세요
# 24                세번째 착장과 아홉번째 착장이 제 취향을 저격했네요 미쳐따 미쳤어
# 25   욕나오게 이쁘네여 언니대박그냥 이쁘다고 하기엔 너무 아쉬워서 뭔가 극강의 표현인 욕...
# 26   이젠 넘사벽 연예인이심 예쁘고 스타일리시하고 화장이며 옷이며 펄펙 꽃길만 걸으세욥 사배님
# 27                                영상 기다렸어요 이사배님 오늘도 기대
# 28     꺅 언니 패션 너무 궁금해서 맨날 열시미봤는데 요즘 하울도 나오고 해서 너무 죠아요오
# 29                                        옌옌이셔몸매랑 얼굴무엇
# ..                                                 ...
# 110                                           메이크업도룩북도
# 111                                           언니너무예쁘자녀
# 112  온니 혹시 기억 나실지 모르겠는데 어제 자라에서 수줍게 사진 찍어달라고 한 팬입니다...
# 113                             증말 이 채널은 편집자님들 센스가 대열일
# 114                                  오늘따라 또 선미가 자꾸 보여요
# 115                                 사배릠 몸매관리법좀여미쳤다 각선미
# 116           왘 너무 아름다우셔서 진짜 넋놓고 봤어요 룩들 다 너무너무 이뻐요 역대급
# 117                                             좋은인생이다
# 118                                          언니 너무 예뻐요
# 119              울언니 인스타보고있었는데 타이밍 대박이다  언니 내가 젤 사랑해요
# 120                                     부제 :  이사배 입덕영상
# 121                                        너무빠빠르다화면전환이
# 122                                       자라에 신발사러 갑니다
# 123  얼굴도 예쁘신데 몸 선도 너무 예쁘셔서 옷이 다 찰떡이에요♡♡♡ 혹시 운동이나 식단...
# 124                       와 언니 자라 찰떡 넘 이쁘게 소화하시는 사배언니♥
# 125                                        1분 1초가 화보임
# 126                            언니 너무 멋있어요 오늘부터 제 우상이에요
# 127                            옷이 사배언니빨 받고있다와 운좋은줄 알아라
# 128                하나같이 다이뻐버리기 있나용❤️메이크업까지 다이쁘고 보고싶었어요
# 129                                          사랑해여왤케이뻐여
# 130                                     오늘도 완죤 여신이세여♥♥
# 131                                          사배님너무 예뻐요
# 132                         사배님이 최고얌화려한거 짱잘어울리셔 그냥 연예인
# 133                          사배님 3번째 룩 메이크업 튜토리얼 plz:)
# 134                                         와 연예인이야 완전
# 135                                 편집 뭐지 진짜 애쓴게 보입니다
# 136                                              잘봤습니다
# 137                                          언니 너무 예뻐요
# 138  이렇게 다 모아서 보니깐 너무너무 좋네요❤의상과 악세사리 하나하나가 다 잘 어울림사...
# 139                                노 젓는 장면에서 “한국 갈라고”
#
# [140 rows x 1 columns]

# %% [markdown]
# # 형태소 분석기를 통한 명사 추출

# %%
#한글 형태소 분석기인 konlpy사용 
#이때 konlpy에는 hannanum, kommoran, kkma, twitter이 있는데 해당 분석에서는 kkma사용
from konlpy.tag import Kkma
from konlpy.tag import Mecab
from konlpy.tag import Twitter
#apply lambda사용

# %%
from konlpy.tag import Twitter

def get_noun(comment_txt):
    twitter = Twitter()
    noun = []
    
    if len(comment_txt)>0:
        tw = twitter.pos(comment_txt)
        for i,j in tw:
            if j == 'Noun':
                noun.append(i)
    return noun
 
comment_result['token'] = comment_result['comment'].apply(lambda x: get_noun(x))

# %%
comment_result['token'] = comment_result['comment'].apply(lambda x: get_noun(x))
# Out:
# C:\Users\tlsal\Anaconda3\lib\site-packages
# 120                                     부제 :  이사배 입덕영상
# 121                                        너무빠빠르다화면전환이
# 122                                       자라에 신발사러 갑니다
# 123  얼굴도 예쁘신데 몸 선도 너무 예쁘셔서 옷이 다 찰떡이에요♡♡♡ 혹시 운동이나 식단...
# 124                       와 언니 자라 찰떡 넘 이쁘게 소화하시는 사배언니♥
# 125                                        1분 1초가 화보임
# 126                            언니 너무 멋있어요 오늘부터 제 우상이에요
# 127                            옷이 사배언니빨 받고있다와 운좋은줄 알아라
# 128                하나같이 다이뻐버리기 있나용❤️메이크업까지 다이쁘고 보고싶었어요
# 129                                          사랑해여왤케이뻐여
# 130                                     오늘도 완죤 여신이세여♥♥
# 131                                          사배님너무 예뻐요
# 132                         사배님이 최고얌화려한거 짱잘어울리셔 그냥 연예인
# 133                          사배님 3번째 룩 메이크업 튜토리얼 plz:)
# 134                                         와 연예인이야 완전
# 135                                 편집 뭐지 진짜 애쓴게 보입니다
# 136                                              잘봤습니다
# 137                                          언니 너무 예뻐요
# 138  이렇게 다 모아서 보니깐 너무너무 좋네요❤의상과 악세사리 하나하나가 다 잘 어울림사...
# 139                                노 젓는 장면에서 “한국 갈라고”
#
#                                                  token
# 0                                        [자라, 슈즈, 투성이]
# 1     [이번, 영상, 편집자, 셩, 정보, 오류, 군데, 댓글, 딕앤, 볼테르, 룩, 혼란]
# 2               [컨텐츠, 역시, 역시, 뭘, 좀, 아시, 센스, 사배, 영상, 오]
# 3                                                   []
# 4    [메이크업, 아티스트, 사배, 유투, 버, 사배, 아이돌, 가수, 사배, 연예인, ...
# 5                                          [이, 영상, 자라]
# 6    [메이크업, 스타일, 진짜, 미쳣어, 반짝, 빤짝, 옷, 악세사리, 거도, 까마귀,...
# 7    [사배, 정말, 사랑, 해, 옛날, 쭉, 아프리카티비, 때, 컨텐츠, 개, 정말, ...
# 8              [미모, 몸매, 기럭지, 또, 무슨, 일이, 언니, 저, 결혼, 잉잉]
# 9                                                   []
# 10                    [옷, 사배, 소화, 옷, 완전, 옷, 사배, 빨, 완전]
# 11                                       [편집자, 능력, 대박]
# 12             [진짜, 포즈, 취하, 거, 천상, 유, 녜, 발끝, 언니, 끼, 모]
# 13                                [세번, 메이크업, 욧, 제, 취향]
# 14                                [요새, 영상, 힐링, 사랑, 해욤]
# 15                 [사배, 헤어스타일, 링, 방법, 앞머리, 부분, 볼륨, 유지]
# 16   [사배, 정말, 신경, 고민, 곧, 학교, 체육대회, 키라, 키라, 메이크업, 전,...
# 17           [마지막, 룩북, 진짜, 녜, 찰떡, 요, 청순, 청순, 화이트, 원피스]
# 18                                [자라, 신발, 맛집, 줄, 몰랐넹]
# 19                                        [언니, 미모, 실화]
# 20                                        [진짜, 모델, 사랑]
# 21                                                  []
# 22                         [오늘, 쏘골져스, 앤, 판타스틱, 우리, 언니]
# 23                                [시험, 기간, 사배, 영상, 정말]
# 24                           [세번, 착, 아홉, 착, 제, 취향, 저격]
# 25   [욕, 여, 언니, 대박, 그냥, 뭔가, 강의, 표현, 욕, 댓글, 욕, 그냥, 따...
# 26      [젠, 넘사벽, 연예인, 이심, 스타일리시, 화장, 옷, 펄펙, 꽃길, 욥, 사배]
# 27                                   [영상, 이사배, 오늘, 기대]
# 28                                 [언니, 패션, 요즘, 하울, 오]
# 29                                    [옌옌이셔몸매, 얼굴, 무엇]
# ..                                                 ...
# 110                                      [메이크업, 도, 북도]
# 111                                           [언니, 자녀]
# 112  [온, 혹시, 기억, 어제, 자라, 사진, 달라, 팬, 쇼핑, 민폐, 거, 어유, ...
# 113                            [증말, 이, 채널, 편집자, 센스, 일]
# 114                                    [오늘, 또, 선미, 자꾸]
# 115                           [사배, 릠, 몸매, 관리, 법좀, 각선미]
# 116                                 [왘, 진짜, 넋, 룩들, 역대]
# 117                                               [인생]
# 118                                               [언니]
# 119                   [언니, 인스타, 타이밍, 대박, 언니, 내, 젤, 사랑]
# 120                                  [부제, 이사배, 입덕, 영상]
# 121                                        [빠, 화면, 전환]
# 122                                           [자라, 신발]
# 123       [얼굴, 데, 몸, 선도, 옷, 찰떡, 혹시, 운동, 식단, 관리, 소개, 것]
# 124                               [언니, 자라, 찰떡, 소화, 사배]
# 125                                            [화보, 임]
# 126                                    [언니, 오늘, 제, 우상]
# 127                                  [옷, 사배, 빨, 운, 은줄]
# 128                                             [메이크업]
# 129                                        [사랑, 케이, 뻐]
# 130                                       [오늘, 완죤, 이세]
# 131                                               [사배]
# 132                               [사배, 최고, 얌, 그냥, 연예인]
# 133                                   [사배, 메이크업, 튜토리얼]
# 134                                          [연예인, 완전]
# 135                                        [편집, 뭐, 진짜]
# 136                                                 []
# 137                                               [언니]
# 138     [보, 의상, 악세사리, 하나, 하나, 어울림, 사배, 정말, 젤예, 다음, 영상]
# 139                                   [노, 장면, 한국, 갈라고]
#
# [140 rows x 2 columns]

# %% [markdown]
# # wordcloud

# %%
from collections import Counter
from wordcloud import WordCloud
#import matplotlib as mpl
import matplotlib.pylab as plt
import numpy as np

# %%
noun_list = []
for i in range(len(comment_result)):
    for j in range(len(comment_result['token'].iloc[i])):
        noun_list.append(comment_result['token'].iloc[i][j])

# %%
counts = Counter(noun_list)
tags = counts.most_common(30)

# %%
tags = counts.most_common(30)

# %%
#bar chart
test = pd.DataFrame({'word':[],
                    'count':[]})
for i in range(len(tags)):
    word = tags[i][0]
    count = tags[i][1]
    
    insert_data = pd.DataFrame({'word':[word],
                                'count':[count]})
    test = test.append(insert_data)

test.index = range(len(test))

# %%
index = np.arange(len(test))
plt.bar(index,test['count'].tolist() )
plt.xlabel('word', fontsize=5)
plt.ylabel('count', fontsize=5)
plt.xticks(index, test['word'].tolist(), fontsize=5, rotation=30)
plt.title('단어 빈도수 시각화')
plt.show()

# %%
wc = WordCloud(font_path='/Users/tlsal/Downloads/탬플릿/NanumSquareL.ttf',background_color='white', width=800, height=600)

print(dict(tags))
cloud = wc.generate_from_frequencies(dict(tags))
plt.figure(figsize=(10, 8))
plt.axis('off')
plt.imshow(cloud)
plt.show()
# Out:
# {'사배': 40, '언니': 38, '진짜': 28, '영상': 18, '옷': 14, '메이크업': 12, '정말': 12, '사랑': 11, '자라': 10, '오늘': 7, '때': 6, '제': 6, '찰떡': 6, '패션': 6, '모델': 5, '대박': 5, '화장': 5, '그냥': 5, '수': 5, '것': 5, '포드': 5, '역시': 4, '뭘': 4, '연예인': 4, '뭐': 4, '미모': 4, '저': 4, '완전': 4, '거': 4, '룩북': 4}
