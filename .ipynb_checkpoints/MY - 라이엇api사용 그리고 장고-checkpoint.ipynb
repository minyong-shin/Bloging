# %%
import requests # 웹 페이지 소스를 얻기 위한 패키지(기본 내장 패키지이다.)
from bs4 import BeautifulSoup # 웹 페이지 소스를 얻기 위한 패키지, 더 간단히 얻을 수 있다는 장점이 있다고 한다.
from datetime import datetime                                # (!pip install beautifulsoup4 으로 다운받을 수 있다.)
import pandas as pd # 데이터를 처리하기 위한 가장 기본적인 패키지
import time # 사이트를 불러올 때, 작업 지연시간을 지정해주기 위한 패키지이다. (사이트가 늦게 켜지면 에러가 발생하기 때문)
import urllib.request #
from selenium.webdriver import Chrome
import json
import re     
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
import datetime as dt
import numpy as np
import pickle
import matplotlib

import matplotlib.pyplot as plt

import numpy as np

# %%
plt.style.use('ggplot')

# %% [markdown]
# 404 - data not found
# 429 - 어느정도 시간지나면 불러올 수 있음

# %%
api_key = 'RGAPI-9966947a-b77e-42da-a66c-12acab2f3fca'

# %% [markdown]
# # 소환사 랭크정보 수집

# %%
sohwan = "https://kr.api.riotgames.com/lol/summoner/v4/summoners/by-name/" +'hide on bush' +'?api_key=' + api_key

# %%
r = requests.get(sohwan)

# %%
r
# Out:
# <Response [200]>

# %%
r.json()['id']
# Out:
# '76URdjLX9GaRHd8sWHWOL4rGF_Z9kU6VPesbPBR1A-ByvA'

# %%
tier_url = "https://kr.api.riotgames.com/lol/league/v4/positions/by-summoner/" + r.json()['id'] +'?api_key=' + api_key

# %%
r2  = requests.get(tier_url)

# %%
r2.json()
# Out:
# [{'leagueId': 'b82a4a63-6fe0-34c1-96c5-bd9a7b8b8201',
#   'leagueName': "Syndra's Masterminds",
#   'queueType': 'RANKED_SOLO_5x5',
#   'position': 'NONE',
#   'tier': 'GRANDMASTER',
#   'rank': 'I',
#   'summonerId': '76URdjLX9GaRHd8sWHWOL4rGF_Z9kU6VPesbPBR1A-ByvA',
#   'summonerName': 'Hide on bush',
#   'leaguePoints': 459,
#   'wins': 229,
#   'losses': 239,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False}]

# %% [markdown]
# #그랜드마스터 게임 기록 -api를 이용해서 url을 뽑기 위해서는 api를 아래와 같이 입력하여 request로 받는다.

# %%
grandmaster = 'https://kr.api.riotgames.com/lol/league/v4/grandmasterleagues/by-queue/RANKED_SOLO_5x5?api_key=' + api_key

# %%
r = requests.get(grandmaster)

# %%
r
# Out:
# <Response [200]>

# %%
league_df = pd.DataFrame(r.json())

# %%
league_df.head()
# Out:
#           tier freshBlood hotStreak inactive leaguePoints losses  \
# 0  GRANDMASTER      False      True    False          632    413
# 1  GRANDMASTER      False     False    False          305    401
# 2  GRANDMASTER      False     False    False          289    489
# 3  GRANDMASTER      False     False    False          407    249
# 4  GRANDMASTER      False     False    False          497    235
#
#                                         summonerId     summonerName veteran  \
# 0  8Lh2YFNNZWxPoJtQ4n9myO8XL8MLtm6O9yClMmQH_YbIRII  Masquerade Lies    True
# 1  4sHLGZlyjilby44sQA18VP_ZK0ncenjo69cL6aE8hOpcR_U           해강고 원딜   False
# 2  e0FUeLo0F_Q1wNTE12ly9-GaUaP3oN2fJG6tU9Eksd_kpjc      Winnie13ear    True
# 3   vr68M2OszLTqk4Jbc47ToLQUYlkeCpMUhx5So6DVmc35sQ       C5o349r36n    True
# 4   iNZZbJm6SH3fgENruxK8D7avnVGeh7FpSnIioZOzI5KZ2A         노력하면길이보여   False
#
#   wins
# 0  454
# 1  399
# 2  497
# 3  280
# 4  228

# %%
league_df.reset_index(inplace=True)
league_entries_df = pd.DataFrame(dict(league_df['entries'])).T
league_df = pd.concat([league_df, league_entries_df], axis=1)

league_df = league_df.drop(['index', 'queue', 'name', 'leagueId', 'entries', 'rank'], axis=1)
league_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 10 columns):
# tier            700 non-null object
# freshBlood      700 non-null object
# hotStreak       700 non-null object
# inactive        700 non-null object
# leaguePoints    700 non-null object
# losses          700 non-null object
# summonerId      700 non-null object
# summonerName    700 non-null object
# veteran         700 non-null object
# wins            700 non-null object
# dtypes: object(10)
# memory usage: 54.8+ KB

# %%
league_df.to_csv('그마데이터.csv',index=False,encoding = 'cp949')

# %%
league_df = league_df.drop(columns='account_id')

# %%
league_df['account_id'] = np.nan

# %%
sohwan = 'https://kr.api.riotgames.com/lol/summoner/v4/summoners/by-name/' + league_df['summonerName'].iloc[15] + '?api_key=' + api_key

# %%
r = requests.get(sohwan)

# %%
r
# Out:
# <Response [200]>

# %%
r.json()
# Out:
# {'id': 'ZpvrCspYtI5ATA0ECX9EZWbMhgiv4zhk6Z-4T1jJfvqxWos',
#  'accountId': 'b40jF9oAYduAsYREIuCAZZ9klHGGOhrI4oHDbW321H6zzwU',
#  'puuid': 'TCXCdRz35yQ2mXkE4frZLOXIkeTd7NW6ZjyqhjadAQ6-1Fpq1tirTuzbK6zTexazlKHjQ4NTZcfgvQ',
#  'name': 'chi ma ni zhon',
#  'profileIconId': 4154,
#  'revisionDate': 1559277059000,
#  'summonerLevel': 166}

# %%
account_id = r.json()['accountId']
league_df.iloc[0, -1] = account_id

# %%
league_df
# Out:
#             tier freshBlood hotStreak inactive leaguePoints losses  \
# 0    GRANDMASTER      False     False    False          214    319
# 1    GRANDMASTER      False     False    False          411    143
# 2    GRANDMASTER       True     False    False          267    149
# 3    GRANDMASTER       True     False    False          207    209
# 4    GRANDMASTER      False     False    False          269     50
# 5    GRANDMASTER      False      True    False          352    273
# 6    GRANDMASTER       True     False    False          604    428
# 7    GRANDMASTER       True     False    False          300    240
# 8    GRANDMASTER      False     False    False          205    107
# 9    GRANDMASTER       True     False    False          587    194
# 10   GRANDMASTER       True      True    False          208    301
# 11   GRANDMASTER      False      True    False          350    303
# 12   GRANDMASTER      False     False    False          351    476
# 13   GRANDMASTER      False     False    False          346    540
# 14   GRANDMASTER       True     False    False          226    653
# 15   GRANDMASTER      False      True    False          369    490
# 16   GRANDMASTER      False     False    False          585    115
# 17   GRANDMASTER      False      True    False          608    303
# 18   GRANDMASTER      False     False    False          336     77
# 19   GRANDMASTER      False     False    False          305     49
# 20   GRANDMASTER      False      True    False          415    469
# 21   GRANDMASTER      False     False    False          524    422
# 22   GRANDMASTER      False     False    False          368    255
# 23   GRANDMASTER      False     False    False          335    249
# 24   GRANDMASTER       True     False    False          319    187
# 25   GRANDMASTER      False     False    False          610    158
# 26   GRANDMASTER      False     False    False          228    311
# 27   GRANDMASTER      False     False    False          250     42
# 28   GRANDMASTER      False     False    False          233    116
# 29   GRANDMASTER       True      True    False          249    376
# ..           ...        ...       ...      ...          ...    ...
# 670  GRANDMASTER      False     False    False          381    445
# 671  GRANDMASTER       True     False    False          509    149
# 672  GRANDMASTER      False     False    False          372    288
# 673  GRANDMASTER      False     False    False          326    166
# 674  GRANDMASTER      False     False    False          540     94
# 675  GRANDMASTER      False     False    False          292    329
# 676  GRANDMASTER      False     False    False          432    124
# 677  GRANDMASTER      False     False    False          487    126
# 678  GRANDMASTER       True      True    False          508    259
# 679  GRANDMASTER      False     False    False          346    228
# 680  GRANDMASTER       True     False    False          215    306
# 681  GRANDMASTER       True     False    False          521    442
# 682  GRANDMASTER      False     False    False          289    440
# 683  GRANDMASTER      False     False    False          514    163
# 684  GRANDMASTER      False     False    False          524    404
# 685  GRANDMASTER      False     False    False          433    480
# 686  GRANDMASTER      False     False    False          318    305
# 687  GRANDMASTER       True     False    False          252     62
# 688  GRANDMASTER      False     False    False          397    503
# 689  GRANDMASTER      False     False    False          315    308
# 690  GRANDMASTER       True     False    False          206    464
# 691  GRANDMASTER      False     False    False          203    124
# 692  GRANDMASTER      False     False    False          225    250
# 693  GRANDMASTER       True     False    False          429     82
# 694  GRANDMASTER      False     False    False          241    204
# 695  GRANDMASTER       True     False    False          352    131
# 696  GRANDMASTER      False     False    False          271     94
# 697  GRANDMASTER      False     False    False          294    327
# 698  GRANDMASTER       True      True    False          230    228
# 699  GRANDMASTER      False     False    False          236    181
#
#                                           summonerId      summonerName  \
# 0    9OXFlX_ickISgaXZpFabTA_d6K9wyrwZ3C4uCDuazac-et4           N4talie
# 1    QIh8n_S_GDCyRGMU6oI58p4W3hnpaHS5ZqXq2PrfA96z0GY  xiao jiang jiang
# 2    IT5EyEMtZuXtqfXyw7MrSaClmIXZJCZ1qvPMvRP0UVOXGNY           RuiRui9
# 3    24ApOP9y-OvAArROqOjt-l2Ibj7xbdwv-Izmi3uft3wuH0s             BludX
# 4     Yk7riyXR5fky3hLLrJhmOCKWfaHDXOQTmwyKzuERCQ-Cvg               금민관
# 5    Ff1EB2ZA8LKabiu8kd7dOlOtMOfQrmYiitJlCpxTdcb7wLg         AF TV 최현욱
# 6    fRfcb_2VLV9kHmcD77d_cnCLYDCJ2feUaGeefGp7S3MIrng         Iron Man9
# 7    -7gOuZ52RRXFaQseUQsPqa501eY7qFQGmbCBJP2jGMwSQ4w             와숨막히네
# 8    bEKvCvC_9dbiR0BlovqWYr_am1nLpgERQLb7yjZ8h20lwk0      Cheoli T 3 T
# 9    MHGNpVILjrQIbFwX7TM9sFRT70vKecLFono6fQIc3BWpenU             wrsIt
# 10    d4I8lFrSEhI7r3r3Nv3IkWJ6EnpBQQG5kM1UMB520LrriQ              GET0
# 11   qXH-LjPifgwMFIUSMlTJmQwma-hNYW3LWRA0J_L-f6e7AA4           ganknam
# 12   w47I5fi8p65ykJJPexrh-LaAsr0RdXla9ZkuZ75PfBsx6Xw          팀원을탓하지말자
# 679  pZe1o2y9wpGPo0ZA7MWM2QD2hlvYG4M5aJ3wfzTgLlVtee8            맛츔법파괘자
# 680  OiLxTzUfsiOCKsCoSa5V15A8kuO02Zjhn4N4LNI_b7B7XOo       wo ai kafei
# 681  055SKUWpxfUpH8nkigUTqgoIUGJuQ2dtH5CDoeLusE-ZQIg         gggggggg1
# 682  dzM-_9kZBaSn-k7LtcZygksiEWTU7k_yD0DgGUukFXnW2ag          팀원에게폐가되자
# 683  IrFfOAMjs_YMs8UtuSuhai4Lnp7q9dfdA5jmnz9y9hER98w            백수 권영재
# 684   oKJ9MgPPtwz0rcSI5HsKquUhh3Ff2_EeGQECkycHZAh5LA          웃음후보 이해석
# 685  edBdonuafFvXdwVXJ9WcNVytZxhE6nOIOH39ITg7QPD2jGc           아가리닥치고해
# 686  UEYZIgi41SSI7dckMfXrchnGXy9jFu42S19jrzT5dxl4Kfk            갱피하기달인
# 687  lsRDvPVp_HQ7mTbpJ2uqbVfHN87z6IuEZkRqo8YBXFtfQgE         Actoz top
# 688  P9KfZ4T5JxNq-LMoP5b4SfkDnjBcKupLyt_5Fr6mkr0EqGo    K For The King
# 689  qX6JmASD2s09PaohYLMs0nWPSEC02ZcHri99DuFBZQsf-fI          내가 돌아왔다o
# 690  lmHsfvSZCEJXSTOmiZNSCkKJRyu4p8I_cVlmn9j08XRz9vI  Cry for the moon
# 691  kxO1Q9N8-faNK_nY3jt5tPH-QF6GgrSL6zYoxl0QNZAf_xE          사람강아지햄스터
# 692   OHJSyhOsFBZIHiZMxLFKvOc_aT3l03Tu3FJN0TWU68Md2w          82110202
# 693  kP6q2ekdoGYe8_YUuRuIOuwrIdRBK-knBmFhSFaUHCaeBZA             너를비웃댜
# 694  3yBS4Y_HXRlRoaDX6IWKl7nX68tIwdlDLUVpKbxjyRTNDWE             Mooz9
# 695  AAxrzasttZtXSNcu0I3Ajb9_8sK38bCeokzSOMcQ-SQQuC8      0 game riven
# 696   xK6FKfDVGRBm5bFSOHzlblitS70-ZKSy83sVuBuDLWCHlQ       xiaohaoaaaa
# 697   fv9MUp9WStQQUqpJcooHbwbyASGMRynWaYqrMwbHWiaIMA     Life is B C D
# 698   53fb5pAxyLDEiVw4WOA1QTIbocNewISzoBuiq9JLvg-adA            TaKerA
# 699   IW79bQwHUpXjXiF7yN_Ff1vyEhv6exfQe6hK-kIiXiBf2g          외쳐주유소갓라카
#
#     veteran wins  account_id
# 0      True  317         NaN
# 1      True  230         NaN
# 2     False  192         NaN
# 3     False  243         NaN
# 4     False   52         NaN
# 5      True  292         NaN
# 6     False  430         NaN
# 7     False  311         NaN
# 8     False  149         NaN
# 9     False  272         NaN
# 10    False  324         NaN
# 11     True  381         NaN
# 12     True  520         NaN
# 13     True  621         NaN
# 14    False  670         NaN
# 15     True  469         NaN
# 16     True  128         NaN
# 17     True  339         NaN
# 18    False   70         NaN
# 19    False   72         NaN
# 20     True  459         NaN
# 21    False  454         NaN
# 22     True  269         NaN
# 23     True  266         NaN
# 24    False  222         NaN
# 25    False  175         NaN
# 26     True  327         NaN
# 27    False   69         NaN
# 28    False  157         NaN
# 29    False  389         NaN
# ..      ...  ...         ...
# 670    True  478         NaN
# 671   False  188         NaN
# 672    True  320         NaN
# 673    True  248         NaN
# 674   False  146         NaN
# 675    True  351         NaN
# 676   False  160         NaN
# 677    True  161         NaN
# 678   False  274         NaN
# 679   False  272         NaN
# 680   False  381         NaN
# 681   False  469         NaN
# 682   False  515         NaN
# 683   False  209         NaN
# 684   False  407         NaN
# 685   False  531         NaN
# 686    True  361         NaN
# 687   False   69         NaN
# 688    True  535         NaN
# 689   False  297         NaN
# 690   False  489         NaN
# 691   False  136         NaN
# 692    True  251         NaN
# 693   False  104         NaN
# 694   False  218         NaN
# 695   False  203         NaN
# 696   False  165         NaN
# 697    True  335         NaN
# 698   False  329         NaN
# 699    True  194         NaN
#
# [700 rows x 11 columns]

# %%
for i in range(len(league_df)):
    try:
        sohwan = 'https://kr.api.riotgames.com/lol/summoner/v4/summoners/by-name/' + league_df['summonerName'].iloc[i] + '?api_key=' + api_key 
        r = requests.get(sohwan)
        
        while r.status_code == 429:
            time.sleep(5)
            sohwan = 'https://kr.api.riotgames.com/lol/summoner/v4/summoners/by-name/' + league_df['summonerName'].iloc[i] + '?api_key=' + api_key 
            r = requests.get(sohwan)
            
        account_id = r.json()['accountId']
        league_df.iloc[i, -1] = account_id
    
    except:
        pass

# %%
league_df
# Out:
#             tier freshBlood hotStreak inactive leaguePoints losses  \
# 0    GRANDMASTER      False     False    False          214    319
# 1    GRANDMASTER      False     False    False          411    143
# 2    GRANDMASTER       True     False    False          267    149
# 3    GRANDMASTER       True     False    False          207    209
# 4    GRANDMASTER      False     False    False          269     50
# 5    GRANDMASTER      False      True    False          352    273
# 6    GRANDMASTER       True     False    False          604    428
# 7    GRANDMASTER       True     False    False          300    240
# 8    GRANDMASTER      False     False    False          205    107
# 9    GRANDMASTER       True     False    False          587    194
# 10   GRANDMASTER       True      True    False          208    301
# 11   GRANDMASTER      False      True    False          350    303
# 12   GRANDMASTER      False     False    False          351    476
# 13   GRANDMASTER      False     False    False          346    540
# 14   GRANDMASTER       True     False    False          226    653
# 15   GRANDMASTER      False      True    False          369    490
# 16   GRANDMASTER      False     False    False          585    115
# 17   GRANDMASTER      False      True    False          608    303
# 18   GRANDMASTER      False     False    False          336     77
# 19   GRANDMASTER      False     False    False          305     49
# 20   GRANDMASTER      False      True    False          415    469
# 21   GRANDMASTER      False     False    False          524    422
# 22   GRANDMASTER      False     False    False          368    255
# 23   GRANDMASTER      False     False    False          335    249
# 24   GRANDMASTER       True     False    False          319    187
# 25   GRANDMASTER      False     False    False          610    158
# 26   GRANDMASTER      False     False    False          228    311
# 27   GRANDMASTER      False     False    False          250     42
# 28   GRANDMASTER      False     False    False          233    116
# 29   GRANDMASTER       True      True    False          249    376
# ..           ...        ...       ...      ...          ...    ...
# 670  GRANDMASTER      False     False    False          381    445
# 671  GRANDMASTER       True     False    False          509    149
# 672  GRANDMASTER      False     False    False          372    288
# 673  GRANDMASTER      False     False    False          326    166
# 674  GRANDMASTER      False     False    False          540     94
# 675  GRANDMASTER      False     False    False          292    329
# 676  GRANDMASTER      False     False    False          432    124
# 677  GRANDMASTER      False     False    False          487    126
# 678  GRANDMASTER       True      True    False          508    259
# 679  GRANDMASTER      False     False    False          346    228
# 680  GRANDMASTER       True     False    False          215    306
# 681  GRANDMASTER       True     False    False          521    442
# 682  GRANDMASTER      False     False    False          289    440
# 683  GRANDMASTER      False     False    False          514    163
# 684  GRANDMASTER      False     False    False          524    404
# 685  GRANDMASTER      False     False    False          433    480
# 686  GRANDMASTER      False     False    False          318    305
# 687  GRANDMASTER       True     False    False          252     62
# 688  GRANDMASTER      False     False    False          397    503
# 689  GRANDMASTER      False     False    False          315    308
# 690  GRANDMASTER       True     False    False          206    464
# 691  GRANDMASTER      False     False    False          203    124
# 692  GRANDMASTER      False     False    False          225    250
# 693  GRANDMASTER       True     False    False          429     82
# 694  GRANDMASTER      False     False    False          241    204
# 695  GRANDMASTER       True     False    False          352    131
# 696  GRANDMASTER      False     False    False          271     94
# 697  GRANDMASTER      False     False    False          294    327
# 698  GRANDMASTER       True      True    False          230    228
# 699  GRANDMASTER      False     False    False          236    181
#
#                                           summonerId      summonerName  \
# 0    9OXFlX_ickISgaXZpFabTA_d6K9wyrwZ3C4uCDuazac-et4           N4talie
# 1    QIh8n_S_GDCyRGMU6oI58p4W3hnpaHS5ZqXq2PrfA96z0GY  xiao jiang jiang
# 2    IT5EyEMtZuXtqfXyw7MrSaClmIXZJCZ1qvPMvRP0UVOXGNY           RuiRui9
# 3    24ApOP9y-OvAArROqOjt-l2Ibj7xbdwv-Izmi3uft3wuH0s             BludX
# 4     Yk7riyXR5fky3hLLrJhmOCKWfaHDXOQTmwyKzuERCQ-Cvg               금민관
# 5    Ff1EB2ZA8LKabiu8kd7dOlOtMOfQrmYiitJlCpxTdcb7wLg         AF TV 최현욱
# 6    fRfcb_2VLV9kHmcD77d_cnCLYDCJ2feUaGeefGp7S3MIrng         Iron Man9
# 7    -7gOuZ52RRXFaQseUQsPqa501eY7qFQGmbCBJP2jGMwSQ4w             와숨막히네
# 8    bEKvCvC_9dbiR0BlovqWYr_am1nLpgERQLb7yjZ8h20lwk0      Cheoli T 3 T
# 9    MHGNpVILjrQIbFwX7TM9sFRT70vKecLFono6fQIc3BWpenU             wrsIt
# 10    d4I8lFrSEhI7r3r3Nv3IkWJ6EnpBQQG5kM1UMB520LrriQ              GET0
# 11   qXH-LjPifgwMFIUSMlTJmQwma-hNYW3LWRA0J_L-f6e7AA4           ganknam
# 12   w47I5fi8p65ykJJPexrh-LaAsr0RdXla9ZkuZ75PfBsx6Xw          팀원을탓하지말자
# 13   SzBvp9PbG-AVGrQS1DFVwWlj30RuyPtVk80DXWYMd83IRUM              S01A
# 14   ltallUKoxlzLInfIG9jr8oq60SS2813GYVS2NXVUAF6_WfU              두근2근
# 15   iM89Q45xIuv2TpO_uGPOllAU_rYuX1L3eTrWAE3ETv6fBkQ        SilenceOB
# 16   yhD5xhsSLSaXzbVe5F_aOKdr1-WU_l7lq4_0GyZMoHXS3OU            순수했던 꿈
# 17   40NhnDbMVuaO1aEF8tPnR6Tphg_mYnaXHol_-dGDha53yGk         iwantwinn
# 18   qaafF5fqTiByGxpgJQyfAP9rVCJTPjK4xIuVZ_HC_LFARwY               살 혼
# 683   False  209  4Q8umHG7vkEWLzGER1dZcI2WJIPiTUxaa2ZmB0je1zAk4y...
# 684   False  407       nJS1xfisWGbcH5r3DVbJ22JsSWrQdhY2hme16MJuZn3Q
# 685   False  531    rnisCimPuLWbhRYIF58KUt-WyVowi8V34xLC6RfctjIFjNs
# 686    True  361    lc4n9PFNnSEwv2yy-jo8B8UgQFp_ymagO8byT6nIwuODqpY
# 687   False   69  CDcXGvl-skUhfYX7CNd08GEwm5Vpx9ADcCeZt8kEd-g82i...
# 688    True  535  jyQIu3GSiE8RPvA9ECrs0CeVrkdiqJYiqZE_dClZUZBC2g...
# 689   False  297    2EsvCc58YNLAGPfRRw89jxigpnLOxymdyAJNO_OeUNa1n0M
# 690   False  489  -HvxAxs84Iwwwr5tmcLkjphh0bGGh5rhIR9SPwK_NEEBJp...
# 691   False  136    Y1fE_TOPDqfW2p4EmBhRgmczA68_G_l0GTBlQJmFz_WsQiI
# 692    True  251       FxADpFael8HH70oDR_fWE4Qxpv1ehFJ89mDibjfGE84t
# 693   False  104  -yaQG0DPEm2-R1JE4KbkXHeJrohvyc6qHd4x22WWYjaP45...
# 694   False  218  YDUxBKotOT8ZolWaplAA-X3Qpm46HZ104gj7xacN-0kHfV...
# 695   False  203  ShpAa_oXchfzaSNJ1KNF-db9e-tjKWc1ljIokECXVBMmls...
# 696   False  165       j9KFPRcUL-74DNPFONjBqzQB_BtkNiLCXfHb6xFHUsZ6
# 697    True  335       Kb8CA_SURoWbUWXvJRWfM7Wn2qE-8zuDFJ8gCvWMYLyg
# 698   False  329       iLt-6ZjZJu4qVBSnfuRtFTR5jbdJQiUS13zL-HFkDUcs
# 699    True  194       Dqq-0QFgo9CusDKUZKbjhmHG-b2n1VAX2gtUx7ze_rjq
#
# [700 rows x 11 columns]

# %%
league_df2 = league_df.fillna('request403')

# %%
league_df3 = league_df2[league_df2['account_id']!='request403']

# %%
league_df3.to_csv('accountid데이터.csv',index = False,encoding='cp949')

# %% [markdown]
# ### 매치데이터

# %% [markdown]
# #accountid를 이용하여 매치데이터 불러오기 -> 최종적으로는 gameid를 이용한 매치 데이터가 필요하므로 gameid를 먼저 불러오자

# %%
match_info_df = pd.DataFrame()

# %%
league_df3['account_id'].iloc[0]
# Out:
# 'xGk6hmYH1xpSIg8dPG7yIx82He4dL_GLkHFN1kVl6MCmjWA'

# %%
season = str(13)

# %%
api_url = 'https://kr.api.riotgames.com/lol/match/v4/matchlists/by-account/' + league_df3['account_id'].iloc[0]  +'?season=' + season + '&api_key=' + api_key

# %%
r = requests.get(api_url)
# Out:
# <Response [200]>

# %%
pd.DataFrame(r.json()['matches'])
# Out:
#     champion      gameId    lane platformId  queue         role  season  \
# 0        203  3676857460  JUNGLE         KR    420         NONE      13
# 1         64  3676779762  JUNGLE         KR    420         NONE      13
# 2         80  3676791079  JUNGLE         KR    420         NONE      13
# 3          5  3676754305    NONE         KR    420  DUO_SUPPORT      13
# 4         64  3676659344  JUNGLE         KR    420         NONE      13
# 5         64  3676683201  JUNGLE         KR    420         NONE      13
# 6         60  3676589494    NONE         KR    420  DUO_SUPPORT      13
# 7         60  3676574309    NONE         KR    420  DUO_SUPPORT      13
# 8        113  3676494716  JUNGLE         KR    420         NONE      13
# 9        203  3676008608  JUNGLE         KR    420         NONE      13
# 10         2  3676013138  JUNGLE         KR    420         NONE      13
# 11        59  3675868503  JUNGLE         KR    420         NONE      13
# 12       412  3675566752    NONE         KR    450  DUO_SUPPORT      13
# 13       107  3675521030     TOP         KR    450          DUO      13
# 14        29  3675475073    NONE         KR    450          DUO      13
# 15        10  3675427249    NONE         KR    450          DUO      13
# 16        38  3675371893    NONE         KR    450  DUO_SUPPORT      13
# 17        67  3675325811    NONE         KR    450  DUO_SUPPORT      13
# 18       113  3675263713  JUNGLE         KR    420         NONE      13
# 19       163  3675198467    NONE         KR    420  DUO_SUPPORT      13
# 20        64  3675180477    NONE         KR    420  DUO_SUPPORT      13
# 21       113  3675142988  JUNGLE         KR    420         NONE      13
# 22        81  3675084841     MID         KR    420          DUO      13
# 23        60  3674842899  JUNGLE         KR    420         NONE      13
# 24        60  3674665491  JUNGLE         KR    420         NONE      13
# 25        92  3674452764    NONE         KR    450          DUO      13
# 26        39  3674442191    NONE         KR    450    DUO_CARRY      13
# 27         6  3674450550  JUNGLE         KR    430         NONE      13
# 28       163  3674388504     MID         KR    430          DUO      13
# 29       203  3674348141  JUNGLE         KR    430         NONE      13
# ..       ...         ...     ...        ...    ...          ...     ...
# 70       111  3671346768     TOP         KR    450  DUO_SUPPORT      13
# 71       122  3671332421    NONE         KR    450  DUO_SUPPORT      13
# 72        64  3671257940    NONE         KR    430  DUO_SUPPORT      13
# 73        11  3671243514  JUNGLE         KR    430         NONE      13
# 74       117  3671189414    NONE         KR    430  DUO_SUPPORT      13
# 75        64  3671140131    NONE         KR    420  DUO_SUPPORT      13
# 76        33  3670131141    NONE         KR    430  DUO_SUPPORT      13
# 77       111  3670046641    NONE         KR    430  DUO_SUPPORT      13
# 78        40  3670100788    NONE         KR    430  DUO_SUPPORT      13
# 79       145  3670036126  JUNGLE         KR    430         NONE      13
# 80        21  3670002946    NONE         KR    430  DUO_SUPPORT      13
# 81        64  3669907807  JUNGLE         KR    420         NONE      13
# 82        60  3669953430    NONE         KR    420  DUO_SUPPORT      13
# 83       203  3669882354    NONE         KR    420  DUO_SUPPORT      13
# 84        79  3669543379     MID         KR    450          DUO      13
# 85       203  3669520702    NONE         KR    450          DUO      13
# 86        39  3669457054     TOP         KR    450         SOLO      13
# 87       142  3665771232    NONE         KR    450  DUO_SUPPORT      13
# 88       114  3665706652    NONE         KR    450  DUO_SUPPORT      13
# 89       420  3665661314    NONE         KR    450  DUO_SUPPORT      13
# 90       121  3665645908    NONE         KR    450  DUO_SUPPORT      13
# 91       266  3665307090  JUNGLE         KR    430         NONE      13
# 92       236  3665237089  BOTTOM         KR    430    DUO_CARRY      13
# 93       145  3665210304  BOTTOM         KR    430    DUO_CARRY      13
# 94        60  3663715340    NONE         KR    420  DUO_SUPPORT      13
# 95        59  3663599943  JUNGLE         KR    420         NONE      13
# 96        60  3663632955  JUNGLE         KR    420         NONE      13
# 97       126  3663527540     TOP         KR    420         SOLO      13
# 98       113  3663510085  JUNGLE         KR    420         NONE      13
# 99        29  3663485148  BOTTOM         KR    420    DUO_CARRY      13
#
#         timestamp
# 0   1558785426058
# 1   1558783247340
# 2   1558780818696
# 3   1558778815052
# 4   1558777205059
# 5   1558775354424
# 6   1558774186184
# 7   1558772618488
# 8   1558769857015
# 9   1558758490269
# 10  1558756159883
# 11  1558753708771
# 12  1558713202305
# 13  1558711490265
# 14  1558710061527
# 15  1558708166507
# 16  1558706753111
# 17  1558705337796
# 18  1558702435829
# 19  1558701102088
# 20  1558698891844
# 21  1558696760272
# 22  1558694048816
# 23  1558689543284
# 24  1558686766203
# 25  1558667446242
# 26  1558666476535
# 27  1558664905229
# 28  1558662193161
# 29  1558660647148
# ..            ...
# 70  1558440970586
# 71  1558439720771
# 72  1558438377794
# 73  1558436857624
# 74  1558435495791
# 75  1558427756712
# 76  1558353518118
# 77  1558352061447
# 78  1558350651969
# 79  1558349037033
# 80  1558347731221
# 81  1558345375121
# 82  1558344108800
# 83  1558339066401
# 84  1558283985471
# 85  1558282536421
# 86  1558280892910
# 87  1558110919461
# 88  1558109450341
# 89  1558107786373
# 90  1558106424439
# 91  1558104148620
# 92  1558101790204
# 93  1558100072396
# 94  1558005627792
# 95  1558003610153
# 96  1558000985729
# 97  1557998606937
# 98  1557995297567
# 99  1557993131978
#
# [100 rows x 8 columns]

# %%
match_info_df = pd.concat([match_info_df, pd.DataFrame(r.json()['matches'])])

# %%
#13시즌의 데이터만을 이용할 것이며 league_df3 => 기존에 수집한 account_id가 있는 league_df
match_info_df = pd.DataFrame()
season = str(13)
for i in range(len(league_df3)):
    try:
        match0 = 'https://kr.api.riotgames.com/lol/match/v4/matchlists/by-account/' + league_df3['account_id'].iloc[i]  +'?season=' + season + '&api_key=' + api_key
        r = requests.get(match0)
        
        while r.status_code == 429:
            time.sleep(5)
            match0 = 'https://kr.api.riotgames.com/lol/match/v4/matchlists/by-account/' + league_df3['account_id'].iloc[i]  +'?season=' + season + '&api_key=' + api_key
            r = requests.get(match0)
            
        match_info_df = pd.concat([match_info_df, pd.DataFrame(r.json()['matches'])])
    
    except:
        print(i)

# %%
match_info_df
# Out:
#        champion      gameId    lane platformId  queue         role  season  \
# 0           203  3676857460  JUNGLE         KR    420         NONE      13
# 1            64  3676779762  JUNGLE         KR    420         NONE      13
# 2            80  3676791079  JUNGLE         KR    420         NONE      13
# 3             5  3676754305    NONE         KR    420  DUO_SUPPORT      13
# 4            64  3676659344  JUNGLE         KR    420         NONE      13
# 5            64  3676683201  JUNGLE         KR    420         NONE      13
# 6            60  3676589494    NONE         KR    420  DUO_SUPPORT      13
# 7            60  3676574309    NONE         KR    420  DUO_SUPPORT      13
# 8           113  3676494716  JUNGLE         KR    420         NONE      13
# 9           203  3676008608  JUNGLE         KR    420         NONE      13
# 10            2  3676013138  JUNGLE         KR    420         NONE      13
# 11           59  3675868503  JUNGLE         KR    420         NONE      13
# 12          412  3675566752    NONE         KR    450  DUO_SUPPORT      13
# 13          107  3675521030     TOP         KR    450          DUO      13
# 14           29  3675475073    NONE         KR    450          DUO      13
# 15           10  3675427249    NONE         KR    450          DUO      13
# 16           38  3675371893    NONE         KR    450  DUO_SUPPORT      13
# 17           67  3675325811    NONE         KR    450  DUO_SUPPORT      13
# 18          113  3675263713  JUNGLE         KR    420         NONE      13
# 19          163  3675198467    NONE         KR    420  DUO_SUPPORT      13
# 20           64  3675180477    NONE         KR    420  DUO_SUPPORT      13
# 21          113  3675142988  JUNGLE         KR    420         NONE      13
# 22           81  3675084841     MID         KR    420          DUO      13
# 23           60  3674842899  JUNGLE         KR    420         NONE      13
# 24           60  3674665491  JUNGLE         KR    420         NONE      13
# 25           92  3674452764    NONE         KR    450          DUO      13
# 26           39  3674442191    NONE         KR    450    DUO_CARRY      13
# 27            6  3674450550  JUNGLE         KR    430         NONE      13
# 28          163  3674388504     MID         KR    430          DUO      13
# 29          203  3674348141  JUNGLE         KR    430         NONE      13
# ...         ...         ...     ...        ...    ...          ...     ...
# 68728         8  3658351082    NONE         KR    450  DUO_SUPPORT      13
# 68729       268  3658020561     MID         KR    430         SOLO      13
# 68730       203  3657908302    NONE         KR    430  DUO_SUPPORT      13
# 68731        59  3657943654  JUNGLE         KR    430         NONE      13
# 68732       268  3657931489    NONE         KR    430          DUO      13
# 68733        18  3657868407  BOTTOM         KR    430    DUO_CARRY      13
# 68734       268  3657845602     MID         KR    430         SOLO      13
# 68735         8  3657834001    NONE         KR    430          DUO      13
# 68736        51  3657831175  BOTTOM         KR    430    DUO_CARRY      13
# 68737       268  3657644799     MID         KR    430         SOLO      13
# 68738       268  3657651106     MID         KR    430         SOLO      13
# 68739       117  3657586441    NONE         KR    420  DUO_SUPPORT      13
# 68740        16  3657509717  BOTTOM         KR    420  DUO_SUPPORT      13
# 68741       268  3654493117     MID         KR    430         SOLO      13
# 68742        51  3654551017  BOTTOM         KR    430    DUO_CARRY      13
# 68743         8  3654510526     MID         KR    430         SOLO      13
# 68744        82  3654434726     TOP         KR    430         SOLO      13
# 68745       122  3654473772     MID         KR    430          DUO      13
# 68746        43  3654463145     MID         KR    450  DUO_SUPPORT      13
# 68747        24  3654481696     TOP         KR    430         SOLO      13
# 68748        20  3654421096  JUNGLE         KR    430         NONE      13
# 68749        74  3654379600     TOP         KR    430         SOLO      13
# 68750         8  3654368598    NONE         KR    430          DUO      13
# 68751       268  3652057741     MID         KR    430         SOLO      13
# 68752       268  3652071051     MID         KR    430         SOLO      13
# 68753        51  3652046695    NONE         KR    430          DUO      13
# 68754       222  3652027741  BOTTOM         KR    430    DUO_CARRY      13
# 68755       268  3652007101     MID         KR    430         SOLO      13
# 68756       268  3651998125     MID         KR    430         SOLO      13
# 68757       268  3651075675     MID         KR    430          DUO      13
#
#            timestamp
# 0      1558785426058
# 1      1558783247340
# 2      1558780818696
# 3      1558778815052
# 4      1558777205059
# 5      1558775354424
# 6      1558774186184
# 7      1558772618488
# 8      1558769857015
# 9      1558758490269
# 10     1558756159883
# 11     1558753708771
# 12     1558713202305
# 13     1558711490265
# 14     1558710061527
# 15     1558708166507
# 16     1558706753111
# 17     1558705337796
# 18     1558702435829
# 19     1558701102088
# 20     1558698891844
# 21     1558696760272
# 22     1558694048816
# 23     1558689543284
# 24     1558686766203
# 25     1558667446242
# 26     1558666476535
# 27     1558664905229
# 28     1558662193161
# 29     1558660647148
# ...              ...
# 68728  1557646926939
# 68729  1557634701827
# 68730  1557633497429
# 68731  1557631580951
# 68732  1557630446956
# 68733  1557628749974
# 68734  1557626859555
# 68735  1557625496493
# 68736  1557623146524
# 68737  1557595028390
# 68738  1557593541800
# 68739  1557592094449
# 68740  1557589979327
# 68741  1557455577892
# 68742  1557453709065
# 68743  1557452129393
# 68744  1557437068171
# 68745  1557435018656
# 68746  1557433208619
# 68747  1557431259747
# 68748  1557429334484
# 68749  1557427470392
# 68750  1557426275296
# 68751  1557258969358
# 68752  1557257393372
# 68753  1557256210231
# 68754  1557254245303
# 68755  1557251851110
# 68756  1557248867895
# 68757  1557183172315
#
# [68758 rows x 8 columns]

# %%
match_info_df.to_csv('매치1.csv',index=False,encoding='cp949')

# %%
match_info_df = pd.read_csv('매치1.csv',engine= 'python')

# %% [markdown]
# # gameid중복제거한 뒤 경기정보 불러오기

# %%
len(match_info_df2)
# Out:
# 33130

# %%
match_info_df2 = match_info_df.drop_duplicates('gameId')

# %%
match_df = pd.DataFrame()

# %%
api_url = 'https://kr.api.riotgames.com/lol/match/v4/matches/' + str(match_info_df2['gameId'].iloc[0]) + '?api_key=' + api_key

# %%
r = requests.get(api_url)

# %%
r = requests.get(api_url,headers = {'user-agent': ('Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko)'
                                                                            'Chrome/71.0.3578.98 Safari/537.36')})

# %%
r
# Out:
# <Response [403]>

# %%
pd.DataFrame(list(r.json().values()), index=list(r.json().keys())).T
# Out:
#        gameId platformId   gameCreation gameDuration queueId mapId seasonId  \
# 0  3676857460         KR  1558785426058         1274     420    11       13
#
#      gameVersion gameMode      gameType  \
# 0  9.10.274.8345  CLASSIC  MATCHED_GAME
#
#                                                teams  \
# 0  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
#
#                                         participants  \
# 0  [{'participantId': 1, 'teamId': 100, 'champion...
#
#                                participantIdentities
# 0  [{'participantId': 1, 'player': {'platformId':...

# %%
match_df = pd.DataFrame()

# %%
match_df = match_df2

# %%
match_fin.index = range(len(match_fin))

# %%
match_fin
# Out:
#        gameCreation gameDuration      gameId gameMode      gameType  \
# 0     1558785426058         1274  3676857460  CLASSIC  MATCHED_GAME
# 1     1558783247340         1720  3676779762  CLASSIC  MATCHED_GAME
# 2     1558780818696         2029  3676791079  CLASSIC  MATCHED_GAME
# 3     1558778815052          917  3676754305  CLASSIC  MATCHED_GAME
# 4     1558777205059         1228  3676659344  CLASSIC  MATCHED_GAME
# 5     1558775354424         1461  3676683201  CLASSIC  MATCHED_GAME
# 6     1558774186184          872  3676589494  CLASSIC  MATCHED_GAME
# 7     1558772618488          924  3676574309  CLASSIC  MATCHED_GAME
# 8     1558769857015         1997  3676494716  CLASSIC  MATCHED_GAME
# 9     1558758490269         1295  3676008608  CLASSIC  MATCHED_GAME
# 4036  1558433308730         1537  3671163952  CLASSIC  MATCHED_GAME
# 4037  1558430037374         1575  3671086461  CLASSIC  MATCHED_GAME
# 4038  1558900629842         2077  3679262689  CLASSIC  MATCHED_GAME
# 4039  1558896547923          716  3679228698  CLASSIC  MATCHED_GAME
# 4040  1558894648411         1381  3679208083  CLASSIC  MATCHED_GAME
# 4041  1558893166209          942  3679196546  CLASSIC  MATCHED_GAME
#
#         gameVersion mapId                              participantIdentities  \
# 0     9.10.274.8345    11  [{'participantId': 1, 'player': {'platformId':...
# 1     9.10.274.8345    11  [{'participantId': 1, 'player': {'platformId':...
# 2     9.10.274.8345    11  [{'participantId': 1, 'player': {'platformId':...
# 3     9.10.274.8345    11  [{'participantId': 1, 'player': {'platformId':...
# 4     9.10.274.8345    11  [{'participantId': 1, 'player': {'platformId':...
# 5     9.10.274.8345    11  [{'participantId': 1, 'player': {'platformId':...
# 6     9.10.274.8345    11  [{'participantId': 1, 'player': {'platformId':...
# 7     9.10.274.8345    11  [{'participantId': 1, 'player': {'platformId':...
# 8     9.10.274.8345    11  [{'participantId': 1, 'player': {'platformId':...
# 9     9.10.274.8345    11  [{'participantId': 1, 'player': {'platformId':...
# 10    9.10.274.8345    11  [{'participantId': 1, 'player': {'platformId':...
# 11    9.10.274.8345    11  [{'participantId': 1, 'player': {'platformId':...
# 12    9.10.274.8345    12  [{'participantId': 1, 'player': {'platformId':...
# 13    9.10.274.8345    12  [{'participantId': 1, 'player': {'platformId':...
# 14    9.10.274.8345    12  [{'participantId': 1, 'player': {'platformId':...
# 15    9.10.274.8345    12  [{'participantId': 1, 'player': {'platformId':...
# 16    9.10.274.8345    12  [{'participantId': 1, 'player': {'platformId':...
# 17    9.10.274.8345    12  [{'participantId': 1, 'player': {'platformId':...
# 18    9.10.274.8345    11  [{'participantId': 1, 'player': {'platformId':...
# 19    9.10.274.8345    11  [{'participantId': 1, 'player': {'platformId':...
# 20    9.10.274.8345    11  [{'participantId': 1, 'player': {'platformId':...
# 21    9.10.274.8345    11  [{'participantId': 1, 'player': {'platformId':...
# 22    9.10.274.8345    11  [{'participantId': 1, 'player': {'platformId':...
# 23    9.10.274.8345    12  [{'participantId': 1, 'player': {'platformId':...
# 24    9.10.274.8345    12  [{'participantId': 1, 'player': {'platformId':...
# 25    9.10.274.8345    11  [{'participantId': 1, 'player': {'platformId':...
# 26    9.10.274.8345    11  [{'participantId': 1, 'player': {'platformId':...
# 27    9.10.274.8345    11  [{'participantId': 1, 'player': {'platformId':...
# 28    9.10.274.8345    11  [{'participantId': 1, 'player': {'platformId':...
# 29    9.10.274.8345    12  [{'participantId': 1, 'player': {'platformId':...
# ...             ...   ...                                                ...
# 4012  9.10.274.8345    11  [{'participantId': 1, 'player': {'platformId':...
# 4013  9.10.274.8345    11  [{'participantId': 1, 'player': {'platformId':...
# 4014  9.10.274.8345    11  [{'participantId': 1, 'player': {'platformId':...
# 4015  9.10.274.8345    11  [{'participantId': 1, 'player': {'platformId':...
# 4016  9.10.274.8345    11  [{'participantId': 1, 'player': {'platformId':...
# 4017  9.10.274.8345    11  [{'participantId': 1, 'player': {'platformId':...
# 4018  9.10.274.8345    11  [{'participantId': 1, 'player': {'platformId':...
# 4019  9.10.274.8345    11  [{'participantId': 1, 'player': {'platformId':...
# 4020  9.10.274.8345    11  [{'participantId': 1, 'player': {'platformId':...
# 4021  9.10.274.8345    11  [{'participantId': 1, 'player': {'platformId':...
# 4022  9.10.274.8345    11  [{'participantId': 1, 'player': {'platformId':...
# 4023  9.10.274.8345    11  [{'participantId': 1, 'player': {'platformId':...
# 4024  9.10.274.8345    11  [{'participantId': 1, 'player': {'platformId':...
# 4025  9.10.274.8345    11  [{'participantId': 1, 'player': {'platformId':...
# 4026  9.10.274.8345    11  [{'participantId': 1, 'player': {'platformId':...
# 4027  9.10.274.8345    11  [{'participantId': 1, 'player': {'platformId':...
# 4028  9.10.273.9316    11  [{'participantId': 1, 'player': {'platformId':...
# 4029  9.10.273.9316    11  [{'participantId': 1, 'player': {'platformId':...
# 4030  9.10.273.9316    11  [{'participantId': 1, 'player': {'platformId':...
# 4031  9.10.273.9316    11  [{'participantId': 1, 'player': {'platformId':...
# 4032  9.10.273.9316    11  [{'participantId': 1, 'player': {'platformId':...
# 4033  9.10.273.9316    11  [{'participantId': 1, 'player': {'platformId':...
# 4034  9.10.273.9316    11  [{'participantId': 1, 'player': {'platformId':...
# 4035  9.10.273.9316    11  [{'participantId': 1, 'player': {'platformId':...
# 4036  9.10.273.9316    11  [{'participantId': 1, 'player': {'platformId':...
# 4037  9.10.273.9316    11  [{'participantId': 1, 'player': {'platformId':...
# 4038  9.10.274.8345    11  [{'participantId': 1, 'player': {'platformId':...
# 4039  9.10.274.8345    11  [{'participantId': 1, 'player': {'platformId':...
# 4040  9.10.274.8345    11  [{'participantId': 1, 'player': {'platformId':...
# 4041  9.10.274.8345    11  [{'participantId': 1, 'player': {'platformId':...
#
#                                            participants platformId queueId  \
# 0     [{'participantId': 1, 'teamId': 100, 'champion...         KR     420
# 1     [{'participantId': 1, 'teamId': 100, 'champion...         KR     420
# 2     [{'participantId': 1, 'teamId': 100, 'champion...         KR     420
# 3     [{'participantId': 1, 'teamId': 100, 'champion...         KR     420
# 4     [{'participantId': 1, 'teamId': 100, 'champion...         KR     420
# 5     [{'participantId': 1, 'teamId': 100, 'champion...         KR     420
# 6     [{'participantId': 1, 'teamId': 100, 'champion...         KR     420
# 7     [{'participantId': 1, 'teamId': 100, 'champion...         KR     420
# 8     [{'participantId': 1, 'teamId': 100, 'champion...         KR     420
# 9     [{'participantId': 1, 'teamId': 100, 'champion...         KR     420
# 10    [{'participantId': 1, 'teamId': 100, 'champion...         KR     420
# 11    [{'participantId': 1, 'teamId': 100, 'champion...         KR     420
# 12    [{'participantId': 1, 'teamId': 100, 'champion...         KR     450
# 13    [{'participantId': 1, 'teamId': 100, 'champion...         KR     450
# 14    [{'participantId': 1, 'teamId': 100, 'champion...         KR     450
# 15    [{'participantId': 1, 'teamId': 100, 'champion...         KR     450
# 16    [{'participantId': 1, 'teamId': 100, 'champion...         KR     450
# 17    [{'participantId': 1, 'teamId': 100, 'champion...         KR     450
# 18    [{'participantId': 1, 'teamId': 100, 'champion...         KR     420
# 19    [{'participantId': 1, 'teamId': 100, 'champion...         KR     420
# 20    [{'participantId': 1, 'teamId': 100, 'champion...         KR     420
# 21    [{'participantId': 1, 'teamId': 100, 'champion...         KR     420
# 22    [{'participantId': 1, 'teamId': 100, 'champion...         KR     420
# 23    [{'participantId': 1, 'teamId': 100, 'champion...         KR     450
# 24    [{'participantId': 1, 'teamId': 100, 'champion...         KR     450
# 25    [{'participantId': 1, 'teamId': 100, 'champion...         KR     430
# 26    [{'participantId': 1, 'teamId': 100, 'champion...         KR     430
# 27    [{'participantId': 1, 'teamId': 100, 'champion...         KR     430
# 28    [{'participantId': 1, 'teamId': 100, 'champion...         KR     430
# 29    [{'participantId': 1, 'teamId': 100, 'champion...         KR     450
# ...                                                 ...        ...     ...
# 4012  [{'participantId': 1, 'teamId': 100, 'champion...         KR     420
# 4013  [{'participantId': 1, 'teamId': 100, 'champion...         KR     420
# 4014  [{'participantId': 1, 'teamId': 100, 'champion...         KR     420
# 4015  [{'participantId': 1, 'teamId': 100, 'champion...         KR     420
# 4016  [{'participantId': 1, 'teamId': 100, 'champion...         KR     420
# 4017  [{'participantId': 1, 'teamId': 100, 'champion...         KR     420
# 4018  [{'participantId': 1, 'teamId': 100, 'champion...         KR     420
# 4019  [{'participantId': 1, 'teamId': 100, 'champion...         KR     420
# 4020  [{'participantId': 1, 'teamId': 100, 'champion...         KR     420
# 4021  [{'participantId': 1, 'teamId': 100, 'champion...         KR     420
# 4022  [{'participantId': 1, 'teamId': 100, 'champion...         KR     420
# 4023  [{'participantId': 1, 'teamId': 100, 'champion...         KR     420
# 4024  [{'participantId': 1, 'teamId': 100, 'champion...         KR     420
# 4025  [{'participantId': 1, 'teamId': 100, 'champion...         KR     420
# 4026  [{'participantId': 1, 'teamId': 100, 'champion...         KR     420
# 4027  [{'participantId': 1, 'teamId': 100, 'champion...         KR     420
# 4028  [{'participantId': 1, 'teamId': 100, 'champion...         KR     420
# 4029  [{'participantId': 1, 'teamId': 100, 'champion...         KR     420
# 4030  [{'participantId': 1, 'teamId': 100, 'champion...         KR     420
# 4031  [{'participantId': 1, 'teamId': 100, 'champion...         KR     420
# 4032  [{'participantId': 1, 'teamId': 100, 'champion...         KR     420
# 4033  [{'participantId': 1, 'teamId': 100, 'champion...         KR     420
# 4034  [{'participantId': 1, 'teamId': 100, 'champion...         KR     420
# 4035  [{'participantId': 1, 'teamId': 100, 'champion...         KR     420
# 4036  [{'participantId': 1, 'teamId': 100, 'champion...         KR     420
# 4037  [{'participantId': 1, 'teamId': 100, 'champion...         KR     420
# 4038  [{'participantId': 1, 'teamId': 100, 'champion...         KR     420
# 4039  [{'participantId': 1, 'teamId': 100, 'champion...         KR     420
# 4040  [{'participantId': 1, 'teamId': 100, 'champion...         KR     420
# 4041  [{'participantId': 1, 'teamId': 100, 'champion...         KR     420
#
#      seasonId status                                              teams
# 0          13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 1          13    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': T...
# 2          13    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': F...
# 3          13    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': T...
# 4          13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 5          13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 6          13    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': T...
# 7          13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 8          13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 9          13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 10         13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 11         13    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': F...
# 12         13    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': T...
# 13         13    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': F...
# 14         13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 15         13    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': T...
# 16         13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 17         13    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': T...
# 18         13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 19         13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 20         13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 21         13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 22         13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 23         13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 24         13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 25         13    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': T...
# 26         13    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': T...
# 27         13    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': F...
# 28         13    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': T...
# 29         13    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': T...
# ...       ...    ...                                                ...
# 4012       13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 4013       13    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': T...
# 4014       13    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': F...
# 4015       13    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': T...
# 4016       13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 4017       13    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': T...
# 4018       13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 4019       13    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': T...
# 4020       13    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': T...
# 4021       13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 4022       13    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': F...
# 4023       13    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': T...
# 4024       13    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': F...
# 4025       13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 4026       13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 4027       13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 4028       13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 4029       13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 4030       13    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': T...
# 4031       13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 4032       13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 4033       13    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': T...
# 4034       13    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': F...
# 4035       13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 4036       13    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': T...
# 4037       13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 4038       13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 4039       13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 4040       13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 4041       13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
#
# [4042 rows x 14 columns]

# %%
for i in range(10000,20000):
    try:
        if i == 10000:
            time.sleep(400)
        
        if i == 11000:
            time.sleep(400)
            
        if i == 12000:
            time.sleep(400)
        
        if i == 13000:
            time.sleep(400)
        
        if i == 14000:
            time.sleep(400)
        if i == 15000:
            time.sleep(400)
        if i == 16000:
            time.sleep(400)
        if i == 17000:
            time.sleep(400)
        if i == 18000:
            time.sleep(400)
        if i == 19000:
            time.sleep(400)            
        api_url='https://kr.api.riotgames.com/lol/match/v4/matches/' + str(match_info_df2['gameId'].iloc[i]) + '?api_key=' + api_key
        r = requests.get(api_url)

        while r.status_code == 429:
            time.sleep(2)
            #time.sleep를 꼭 해줘야함 안그러면 request 잦은 사용으로 블랙리스트가 됨
            api_url='https://kr.api.riotgames.com/lol/match/v4/matches/' + str(match_info_df2['gameId'].iloc[i]) + '?api_key=' + api_key
            r = requests.get(api_url)
        
        mat = pd.DataFrame(list(r.json().values()), index=list(r.json().keys())).T
        match_fin = pd.concat([match_fin,mat])

    except:
        pass
# Out:
# C:\Users\tlsal\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False

# %%
match_fin.index = range(len(match_fin))

# %%
with open('임의저장2.pickle','wb') as f:
    pickle.dump(match_fin,f,pickle.HIGHEST_PROTOCOL)

# %%
na_ls = list(match_dff.fillna('requestx')[match_dff.fillna('requestx')['gameDuration']=='requestx'].index)

# %%
match_dff = match_dff.drop(index=na_ls)

# %%
match_fin = pd.concat([match_dff,data])

# %%
match_fin = match_fin.head(17500)

# %%
match_fin
# Out:
#         gameCreation gameDuration      gameId gameMode      gameType  \
# 0      1558785426058         1274  3676857460  CLASSIC  MATCHED_GAME
# 1      1558783247340         1720  3676779762  CLASSIC  MATCHED_GAME
# 2      1558780818696         2029  3676791079  CLASSIC  MATCHED_GAME
# 3      1558778815052          917  3676754305  CLASSIC  MATCHED_GAME
# 4      1558777205059         1228  3676659344  CLASSIC  MATCHED_GAME
# 5      1558775354424         1461  3676683201  CLASSIC  MATCHED_GAME
# 6      1558774186184          872  3676589494  CLASSIC  MATCHED_GAME
# 7      1558772618488          924  3676574309  CLASSIC  MATCHED_GAME
# 8      1558769857015         1997  3676494716  CLASSIC  MATCHED_GAME
# 9      1558758490269         1295  3676008608  CLASSIC  MATCHED_GAME
# 10     1558756159883         1695  3676013138  CLASSIC  MATCHED_GAME
# 11     1558753708771         1856  3675868503  CLASSIC  MATCHED_GAME
# 12     1558713202305         1058  3675566752     ARAM  MATCHED_GAME
# 13     1558711490265         1357  3675521030     ARAM  MATCHED_GAME
# 14     1558710061527         1116  3675475073     ARAM  MATCHED_GAME
# 15     1558708166507         1191  3675427249     ARAM  MATCHED_GAME
# 16     1558706753111          803  3675371893     ARAM  MATCHED_GAME
# 17     1558705337796         1176  3675325811     ARAM  MATCHED_GAME
# 18     1558702435829         1842  3675263713  CLASSIC  MATCHED_GAME
# 19     1558701102088          979  3675198467  CLASSIC  MATCHED_GAME
# 20     1558696760272         1242  3675142988  CLASSIC  MATCHED_GAME
# 21     1558694048816         1868  3675084841  CLASSIC  MATCHED_GAME
# 22     1558689543284         1741  3674842899  CLASSIC  MATCHED_GAME
# 23     1558667446242         1126  3674452764     ARAM  MATCHED_GAME
# 24     1558666476535          742  3674442191     ARAM  MATCHED_GAME
# 25     1558664905229         1338  3674450550  CLASSIC  MATCHED_GAME
# 26     1558662193161         2467  3674388504  CLASSIC  MATCHED_GAME
# 27     1558660647148         1266  3674348141  CLASSIC  MATCHED_GAME
# 28     1558659193278         1225  3674337263  CLASSIC  MATCHED_GAME
# 29     1558658032574          919  3674396112     ARAM  MATCHED_GAME
# ...              ...          ...         ...      ...           ...
# 17470  1558729842180         2018  3675766576  CLASSIC  MATCHED_GAME
# 17471  1558727627301         1741  3675745224  CLASSIC  MATCHED_GAME
# 17472  1558726319414          925  3675754035  CLASSIC  MATCHED_GAME
# 17473  1558722899310         1944  3675709679  CLASSIC  MATCHED_GAME
# 17474  1558683303750         1852  3674577273  CLASSIC  MATCHED_GAME
# 17475  1558681265552         1432  3674572744  CLASSIC  MATCHED_GAME
# 17476  1558679218043         1247  3674478858  CLASSIC  MATCHED_GAME
13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 24          13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 25          13    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': T...
# 26          13    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': T...
# 27          13    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': F...
# 28          13    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': T...
# 29          13    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': T...
# ...        ...    ...                                                ...
# 17470       13    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': F...
# 17471       13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 17472       13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 17473       13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 17474       13    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': F...
# 17475       13    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': F...
# 17476       13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 17477       13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 17478       13    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': T...
# 17479       13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 17480       13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 17481       13    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': F...
# 17482       13    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': T...
# 17483       13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 17484       13    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': F...
# 17485       13    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': F...
# 17486       13    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': T...
# 17487       13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 17488       13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 17489       13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 17490       13    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': F...
# 17491       13    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': T...
# 17492       13    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': F...
# 17493       13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 17494       13    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': T...
# 17495       13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 17496       13    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': T...
# 17497       13    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': T...
# 17498       13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 17499       13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
#
# [17500 rows x 14 columns]

# %%
with open('롤17500개.pickle','wb') as f:
    pickle.dump(match_fin,f,pickle.HIGHEST_PROTOCOL)

# %%
match_df.index = range(len(match_df))

# %%
match_df
# Out:
#        gameCreation gameDuration       gameId gameMode      gameType  \
# 0       1.55879e+12         1274  3.67686e+09  CLASSIC  MATCHED_GAME
# 1       1.55878e+12         1720  3.67678e+09  CLASSIC  MATCHED_GAME
# 2       1.55878e+12         2029  3.67679e+09  CLASSIC  MATCHED_GAME
# 3       1.55878e+12          917  3.67675e+09  CLASSIC  MATCHED_GAME
# 4       1.55878e+12         1228  3.67666e+09  CLASSIC  MATCHED_GAME
# 5       1.55878e+12         1461  3.67668e+09  CLASSIC  MATCHED_GAME
# 6       1.55877e+12          872  3.67659e+09  CLASSIC  MATCHED_GAME
# 7       1.55877e+12          924  3.67657e+09  CLASSIC  MATCHED_GAME
# 8       1.55877e+12         1997  3.67649e+09  CLASSIC  MATCHED_GAME
# 9       1.55876e+12         1295  3.67601e+09  CLASSIC  MATCHED_GAME
# 10      1.55876e+12         1695  3.67601e+09  CLASSIC  MATCHED_GAME
# 11      1.55875e+12         1856  3.67587e+09  CLASSIC  MATCHED_GAME
# 12      1.55871e+12         1058  3.67557e+09     ARAM  MATCHED_GAME
# 13      1.55871e+12         1357  3.67552e+09     ARAM  MATCHED_GAME
# 14      1.55871e+12         1116  3.67548e+09     ARAM  MATCHED_GAME
# 15      1.55871e+12         1191  3.67543e+09     ARAM  MATCHED_GAME
# 16      1.55871e+12          803  3.67537e+09     ARAM  MATCHED_GAME
# 17      1.55871e+12         1176  3.67533e+09     ARAM  MATCHED_GAME
# 18       1.5587e+12         1842  3.67526e+09  CLASSIC  MATCHED_GAME
# 19       1.5587e+12          979   3.6752e+09  CLASSIC  MATCHED_GAME
# 20       1.5587e+12          913  3.67518e+09  CLASSIC  MATCHED_GAME
# 21       1.5587e+12         1242  3.67514e+09  CLASSIC  MATCHED_GAME
# 22      1.55869e+12         1868  3.67508e+09  CLASSIC  MATCHED_GAME
# 23      1.55869e+12         1741  3.67484e+09  CLASSIC  MATCHED_GAME
# 24      1.55869e+12         2037  3.67467e+09  CLASSIC  MATCHED_GAME
# 25      1.55867e+12         1126  3.67445e+09     ARAM  MATCHED_GAME
# 26      1.55867e+12          742  3.67444e+09     ARAM  MATCHED_GAME
# 27      1.55866e+12         1338  3.67445e+09  CLASSIC  MATCHED_GAME
# 28      1.55866e+12         2467  3.67439e+09  CLASSIC  MATCHED_GAME
# 29      1.55866e+12         1266  3.67435e+09  CLASSIC  MATCHED_GAME
# ...             ...          ...          ...      ...           ...
# 4020  1558593151894         1212   3673239094  CLASSIC  MATCHED_GAME
# 4021  1558591963011          896   3673227385  CLASSIC  MATCHED_GAME
[{'participantId': 1, 'teamId': 100, 'champion...         KR     420
# 4037  [{'participantId': 1, 'teamId': 100, 'champion...         KR     420
# 4038  [{'participantId': 1, 'teamId': 100, 'champion...         KR     420
# 4039  [{'participantId': 1, 'teamId': 100, 'champion...         KR     420
# 4040  [{'participantId': 1, 'teamId': 100, 'champion...         KR     420
# 4041  [{'participantId': 1, 'teamId': 100, 'champion...         KR     420
# 4042  [{'participantId': 1, 'teamId': 100, 'champion...         KR     420
# 4043  [{'participantId': 1, 'teamId': 100, 'champion...         KR     420
# 4044  [{'participantId': 1, 'teamId': 100, 'champion...         KR     420
# 4045  [{'participantId': 1, 'teamId': 100, 'champion...         KR     420
# 4046  [{'participantId': 1, 'teamId': 100, 'champion...         KR     420
# 4047  [{'participantId': 1, 'teamId': 100, 'champion...         KR     420
# 4048  [{'participantId': 1, 'teamId': 100, 'champion...         KR     420
# 4049  [{'participantId': 1, 'teamId': 100, 'champion...         KR     420
#
#      seasonId status                                              teams
# 0          13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 1          13    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': T...
# 2          13    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': F...
# 3          13    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': T...
# 4          13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 5          13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 6          13    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': T...
# 7          13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 8          13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 9          13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 10         13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 11         13    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': F...
# 12         13    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': T...
# 13         13    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': F...
# 14         13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 15         13    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': T...
# 16         13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 17         13    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': T...
# 18         13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 19         13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 20         13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 21         13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 22         13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 23         13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 24         13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 25         13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 26         13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 27         13    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': T...
# 28         13    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': T...
# 29         13    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': F...
# ...       ...    ...                                                ...
# 4020       13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 4021       13    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': T...
# 4022       13    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': F...
# 4023       13    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': T...
# 4024       13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 4025       13    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': T...
# 4026       13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 4027       13    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': T...
# 4028       13    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': T...
# 4029       13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 4030       13    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': F...
# 4031       13    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': T...
# 4032       13    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': F...
# 4033       13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 4034       13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 4035       13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 4036       13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 4037       13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 4038       13    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': T...
# 4039       13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 4040       13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 4041       13    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': T...
# 4042       13    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': F...
# 4043       13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 4044       13    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': T...
# 4045       13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 4046       13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 4047       13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 4048       13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 4049       13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
#
# [4050 rows x 14 columns]

# %% [markdown]
# # pickle을 활용한 데이터 type저장

# %%
match_df2 = match_df.iloc[2100:,:]

# %%
match_df2.index = range(len(match_df2))

# %%
import pickle

with open('data.pickle','wb') as f:
    pickle.dump(match_df2,f,pickle.HIGHEST_PROTOCOL)

# %%
with open('data.pickle','rb') as f:
    data = pickle.load(f)

# %%
data
# Out:
#        gameCreation gameDuration      gameId gameMode      gameType  \
# 0     1558136356934         2012  3665928692  CLASSIC  MATCHED_GAME
# 1     1558134176964         1443  3665907691  CLASSIC  MATCHED_GAME
# 2     1558034665393         1726  3664466395     ARAM  MATCHED_GAME
# 3     1557922186466         2035  3662600644  CLASSIC  MATCHED_GAME
# 4     1557694845761         1309  3659287929     ARAM  MATCHED_GAME
# 5     1557692338666         2074  3659286913  CLASSIC  MATCHED_GAME
# 6     1557689210885         2086  3659343212  CLASSIC  MATCHED_GAME
# 7     1557598756354         1423  3657692882     ARAM  MATCHED_GAME
# 8     1557587813973         1185  3657502389     ARAM  MATCHED_GAME
# 9     1557507846497         1069  3655684988  CLASSIC  MATCHED_GAME
# 10    1557505256345         1594  3655677353  CLASSIC  MATCHED_GAME
# 11    1557504616681          198  3655665362  CLASSIC  MATCHED_GAME
# 12    1557502585479         1421  3655579810     ARAM  MATCHED_GAME
# 13    1557233379927          747  3651772072     ARAM  MATCHED_GAME
# 14    1557171309397         1110  3651071382     ARAM  MATCHED_GAME
# 15    1556478810270         1203  3639342441     ARAM  MATCHED_GAME
# 16    1556477489775         1079  3639390056     ARAM  MATCHED_GAME
# 17    1556475661969         1337  3639330126     ARAM  MATCHED_GAME
# 18    1556474455669          996  3639327470     ARAM  MATCHED_GAME
# 19    1556473249216          949  3639306854     ARAM  MATCHED_GAME
# 20    1556288998477         1537  3636149475  CLASSIC  MATCHED_GAME
# 21    1556286005646         1600  3636089364     ARAM  MATCHED_GAME
# 22    1556280639600          931  3636001321  CLASSIC  MATCHED_GAME
# 23    1556213608698         2012  3635086835  CLASSIC  MATCHED_GAME
# 24    1556212997634          196  3635125519  CLASSIC  MATCHED_GAME
# 25    1556211508340          968  3635113829     ARAM  MATCHED_GAME
# 26    1556210437090          844  3635112208     ARAM  MATCHED_GAME
# 27    1556208531285         1427  3634999464     ARAM  MATCHED_GAME
# 28    1556207384140          827  3635007055     ARAM  MATCHED_GAME
# 29    1556197539758         1520  3634900622  CLASSIC  MATCHED_GAME
9.8.270.9450    12  [{'participantId': 1, 'player': {'platformId':...
# 22     9.8.270.9450    11  [{'participantId': 1, 'player': {'platformId':...
# 23     9.8.270.9450    11  [{'participantId': 1, 'player': {'platformId':...
# 24     9.8.270.9450    11  [{'participantId': 1, 'player': {'platformId':...
# 25     9.8.270.9450    12  [{'participantId': 1, 'player': {'platformId':...
# 26     9.8.270.9450    12  [{'participantId': 1, 'player': {'platformId':...
# 27     9.8.270.9450    12  [{'participantId': 1, 'player': {'platformId':...
# 28     9.8.270.9450    12  [{'participantId': 1, 'player': {'platformId':...
# 29     9.8.270.9450    11  [{'participantId': 1, 'player': {'platformId':...
# ...             ...   ...                                                ...
# 1920  9.10.274.8345    11  [{'participantId': 1, 'player': {'platformId':...
# 1921  9.10.274.8345    11  [{'participantId': 1, 'player': {'platformId':...
# 1922  9.10.274.8345    11  [{'participantId': 1, 'player': {'platformId':...
# 1923  9.10.274.8345    11  [{'participantId': 1, 'player': {'platformId':...
# 1924  9.10.274.8345    11  [{'participantId': 1, 'player': {'platformId':...
# 1925  9.10.274.8345    11  [{'participantId': 1, 'player': {'platformId':...
# 1926  9.10.274.8345    11  [{'participantId': 1, 'player': {'platformId':...
# 1927  9.10.274.8345    11  [{'participantId': 1, 'player': {'platformId':...
# 1928  9.10.274.8345    11  [{'participantId': 1, 'player': {'platformId':...
# 1929  9.10.274.8345    11  [{'participantId': 1, 'player': {'platformId':...
# 1930  9.10.274.8345    11  [{'participantId': 1, 'player': {'platformId':...
# 1931  9.10.274.8345    11  [{'participantId': 1, 'player': {'platformId':...
# 1932  9.10.274.8345    11  [{'participantId': 1, 'player': {'platformId':...
# 1933  9.10.274.8345    11  [{'participantId': 1, 'player': {'platformId':...
# 1934  9.10.274.8345    11  [{'participantId': 1, 'player': {'platformId':...
# 1935  9.10.274.8345    11  [{'participantId': 1, 'player': {'platformId':...
# 1936  9.10.273.9316    11  [{'participantId': 1, 'player': {'platformId':...
# 1937  9.10.273.9316    11  [{'participantId': 1, 'player': {'platformId':...
# 1938  9.10.273.9316    11  [{'participantId': 1, 'player': {'platformId':...
# 1939  9.10.273.9316    11  [{'participantId': 1, 'player': {'platformId':...
# 1940  9.10.273.9316    11  [{'participantId': 1, 'player': {'platformId':...
# 1941  9.10.273.9316    11  [{'participantId': 1, 'player': {'platformId':...
# 1942  9.10.273.9316    11  [{'participantId': 1, 'player': {'platformId':...
# 1943  9.10.273.9316    11  [{'participantId': 1, 'player': {'platformId':...
# 1944  9.10.273.9316    11  [{'participantId': 1, 'player': {'platformId':...
# 1945  9.10.273.9316    11  [{'participantId': 1, 'player': {'platformId':...
# 1946  9.10.274.8345    11  [{'participantId': 1, 'player': {'platformId':...
# 1947  9.10.274.8345    11  [{'participantId': 1, 'player': {'platformId':...
# 1948  9.10.274.8345    11  [{'participantId': 1, 'player': {'platformId':...
# 1949  9.10.274.8345    11  [{'participantId': 1, 'player': {'platformId':...
#
#                                            participants platformId queueId  \
# 0     [{'participantId': 1, 'teamId': 100, 'champion...         KR     420
# 1     [{'participantId': 1, 'teamId': 100, 'champion...         KR     420
# 2     [{'participantId': 1, 'teamId': 100, 'champion...         KR     450
# 3     [{'participantId': 1, 'teamId': 100, 'champion...         KR     430
# 4     [{'participantId': 1, 'teamId': 100, 'champion...         KR     450
# 5     [{'participantId': 1, 'teamId': 100, 'champion...         KR     430
# 6     [{'participantId': 1, 'teamId': 100, 'champion...         KR     430
# 7     [{'participantId': 1, 'teamId': 100, 'champion...         KR     450
# 8     [{'participantId': 1, 'teamId': 100, 'champion...         KR     450
# 9     [{'participantId': 1, 'teamId': 100, 'champion...         KR     430
# 10    [{'participantId': 1, 'teamId': 100, 'champion...         KR     430
# 11    [{'participantId': 1, 'teamId': 100, 'champion...         KR     430
# 12    [{'participantId': 1, 'teamId': 100, 'champion...         KR     450
# 13    [{'participantId': 1, 'teamId': 100, 'champion...         KR     450
# 14    [{'participantId': 1, 'teamId': 100, 'champion...         KR     450
# 15    [{'participantId': 1, 'teamId': 100, 'champion...         KR     450
# 16    [{'participantId': 1, 'teamId': 100, 'champion...         KR     450
# 17    [{'participantId': 1, 'teamId': 100, 'champion...         KR     450
# 18    [{'participantId': 1, 'teamId': 100, 'champion...         KR     450
# 19    [{'participantId': 1, 'teamId': 100, 'champion...         KR     450
# 20    [{'participantId': 1, 'teamId': 100, 'champion...         KR     420
# 21    [{'participantId': 1, 'teamId': 100, 'champion...         KR     450
# 22    [{'participantId': 1, 'teamId': 100, 'champion...         KR     420
# 23    [{'participantId': 1, 'teamId': 100, 'champion...         KR     430
# 24    [{'participantId': 1, 'teamId': 100, 'champion...         KR     430
# 25    [{'participantId': 1, 'teamId': 100, 'champion...         KR     450
# 26    [{'participantId': 1, 'teamId': 100, 'champion...         KR     450
# 27    [{'participantId': 1, 'teamId': 100, 'champion...         KR     450
# 28    [{'participantId': 1, 'teamId': 100, 'champion...         KR     450
# 29    [{'participantId': 1, 'teamId': 100, 'champion...         KR     420
# ...                                                 ...        ...     ...
# 1920  [{'participantId': 1, 'teamId': 100, 'champion...         KR     420
# 1921  [{'participantId': 1, 'teamId': 100, 'champion...         KR     420
# 1922  [{'participantId': 1, 'teamId': 100, 'champion...         KR     420
# 1923  [{'participantId': 1, 'teamId': 100, 'champion...         KR     420
# 1924  [{'participantId': 1, 'teamId': 100, 'champion...         KR     420
# 1925  [{'participantId': 1, 'teamId': 100, 'champion...         KR     420
# 1926  [{'participantId': 1, 'teamId': 100, 'champion...         KR     420
# 1927  [{'participantId': 1, 'teamId': 100, 'champion...         KR     420
# 1928  [{'participantId': 1, 'teamId': 100, 'champion...         KR     420
# 1929  [{'participantId': 1, 'teamId': 100, 'champion...         KR     420
# 1930  [{'participantId': 1, 'teamId': 100, 'champion...         KR     420
# 1931  [{'participantId': 1, 'teamId': 100, 'champion...         KR     420
# 1932  [{'participantId': 1, 'teamId': 100, 'champion...         KR     420
# 1933  [{'participantId': 1, 'teamId': 100, 'champion...         KR     420
# 1934  [{'participantId': 1, 'teamId': 100, 'champion...         KR     420
# 1935  [{'participantId': 1, 'teamId': 100, 'champion...         KR     420
# 1936  [{'participantId': 1, 'teamId': 100, 'champion...         KR     420
# 1937  [{'participantId': 1, 'teamId': 100, 'champion...         KR     420
# 1938  [{'participantId': 1, 'teamId': 100, 'champion...         KR     420
# 1939  [{'participantId': 1, 'teamId': 100, 'champion...         KR     420
# 1940  [{'participantId': 1, 'teamId': 100, 'champion...         KR     420
# 1941  [{'participantId': 1, 'teamId': 100, 'champion...         KR     420
# 1942  [{'participantId': 1, 'teamId': 100, 'champion...         KR     420
# 1943  [{'participantId': 1, 'teamId': 100, 'champion...         KR     420
# 1944  [{'participantId': 1, 'teamId': 100, 'champion...         KR     420
# 1945  [{'participantId': 1, 'teamId': 100, 'champion...         KR     420
# 1946  [{'participantId': 1, 'teamId': 100, 'champion...         KR     420
# 1947  [{'participantId': 1, 'teamId': 100, 'champion...         KR     420
# 1948  [{'participantId': 1, 'teamId': 100, 'champion...         KR     420
# 1949  [{'participantId': 1, 'teamId': 100, 'champion...         KR     420
#
#      seasonId status                                              teams
# 0          13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 1          13    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': F...
# 2          13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 3          13    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': T...
# 4          13    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': T...
# 5          13    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': F...
# 6          13    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': F...
# 7          13    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': T...
# 8          13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 9          13    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': T...
# 10         13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 11         13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 12         13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 13         13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 14         13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 15         13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 16         13    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': T...
# 17         13    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': T...
# 18         13    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': T...
# 19         13    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': T...
# 20         13    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': T...
# 21         13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 22         13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 23         13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 24         13    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': F...
# 25         13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 26         13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 27         13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 28         13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 29         13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# ...       ...    ...                                                ...
# 1920       13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 1921       13    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': T...
# 1922       13    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': F...
# 1923       13    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': T...
# 1924       13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 1925       13    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': T...
# 1926       13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 1927       13    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': T...
# 1928       13    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': T...
# 1929       13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 1930       13    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': F...
# 1931       13    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': T...
# 1932       13    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': F...
# 1933       13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 1934       13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 1935       13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 1936       13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 1937       13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 1938       13    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': T...
# 1939       13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 1940       13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 1941       13    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': T...
# 1942       13    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': F...
# 1943       13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 1944       13    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': T...
# 1945       13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 1946       13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 1947       13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 1948       13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 1949       13    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
#
# [1950 rows x 14 columns]

# %% [markdown]
# # 수집한 데이터 저장 갱신

# %%
match_df2 = match_df

# %%
match_df2 = match_df.head(2150)

# %%
match_df2.to_csv('매치분석데이터.csv',index=False,encoding='cp949',mode='w') #타입 그대로 저장하는 방법

# %%
match_df2 = pd.read_csv('매치분석데이터.csv',engine='python', dtype='unicode')

# %%
match_df2
# Out:
#       gameCreation  gameDuration        gameId gameMode      gameType  \
# 0     1.558785e+12        1274.0  3.676857e+09  CLASSIC  MATCHED_GAME
# 1     1.558783e+12        1720.0  3.676780e+09  CLASSIC  MATCHED_GAME
# 2     1.558781e+12        2029.0  3.676791e+09  CLASSIC  MATCHED_GAME
# 3     1.558779e+12         917.0  3.676754e+09  CLASSIC  MATCHED_GAME
# 4     1.558777e+12        1228.0  3.676659e+09  CLASSIC  MATCHED_GAME
# 5     1.558775e+12        1461.0  3.676683e+09  CLASSIC  MATCHED_GAME
# 6     1.558774e+12         872.0  3.676589e+09  CLASSIC  MATCHED_GAME
# 7     1.558773e+12         924.0  3.676574e+09  CLASSIC  MATCHED_GAME
# 4034  1.558503e+12        1177.0  3.672374e+09  CLASSIC  MATCHED_GAME
# 4035  1.558501e+12        1167.0  3.672331e+09  CLASSIC  MATCHED_GAME
# 4036  1.558464e+12        1224.0  3.671811e+09  CLASSIC  MATCHED_GAME
# 4037  1.558456e+12        1312.0  3.671672e+09  CLASSIC  MATCHED_GAME
# 4038  1.558454e+12        1256.0  3.671628e+09  CLASSIC  MATCHED_GAME
# 4039  1.558453e+12        1547.0  3.671585e+09  CLASSIC  MATCHED_GAME
# 4040  1.558445e+12        1570.0  3.671370e+09  CLASSIC  MATCHED_GAME
# 4041  1.558440e+12        1396.0  3.671322e+09  CLASSIC  MATCHED_GAME
# 4042  1.558437e+12        1622.0  3.671274e+09  CLASSIC  MATCHED_GAME
# 4043  1.558435e+12         914.0  3.671179e+09  CLASSIC  MATCHED_GAME
# 4044  1.558433e+12        1537.0  3.671164e+09  CLASSIC  MATCHED_GAME
# 4045  1.558430e+12        1575.0  3.671086e+09  CLASSIC  MATCHED_GAME
# 4046  1.558901e+12        2077.0  3.679263e+09  CLASSIC  MATCHED_GAME
# 4047  1.558897e+12         716.0  3.679229e+09  CLASSIC  MATCHED_GAME
# 4048  1.558895e+12        1381.0  3.679208e+09  CLASSIC  MATCHED_GAME
# 4049  1.558893e+12         942.0  3.679197e+09  CLASSIC  MATCHED_GAME
#
#         gameVersion  mapId                              participantIdentities  \
# 0     9.10.274.8345   11.0  [{'participantId': 1, 'player': {'platformId':...
# 1     9.10.274.8345   11.0  [{'participantId': 1, 'player': {'platformId':...
# 2     9.10.274.8345   11.0  [{'participantId': 1, 'player': {'platformId':...
# 3     9.10.274.8345   11.0  [{'participantId': 1, 'player': {'platformId':...
# 4     9.10.274.8345   11.0  [{'participantId': 1, 'player': {'platformId':...
# 5     9.10.274.8345   11.0  [{'participantId': 1, 'player': {'platformId':...
# 6     9.10.274.8345   11.0  [{'participantId': 1, 'player': {'platformId':...
# 7     9.10.274.8345   11.0  [{'participantId': 1, 'player': {'platformId':...
# 8     9.10.274.8345   11.0  [{'participantId': 1, 'player': {'platformId':...
# 9     9.10.274.8345   11.0  [{'participantId': 1, 'player': {'platformId':...
# 10    9.10.274.8345   11.0  [{'participantId': 1, 'player': {'platformId':...
# 11    9.10.274.8345   11.0  [{'participantId': 1, 'player': {'platformId':...
# 12    9.10.274.8345   12.0  [{'participantId': 1, 'player': {'platformId':...
# 13    9.10.274.8345   12.0  [{'participantId': 1, 'player': {'platformId':...
# 14    9.10.274.8345   12.0  [{'participantId': 1, 'player': {'platformId':...
# 15    9.10.274.8345   12.0  [{'participantId': 1, 'player': {'platformId':...
# 16    9.10.274.8345   12.0  [{'participantId': 1, 'player': {'platformId':...
# 17    9.10.274.8345   12.0  [{'participantId': 1, 'player': {'platformId':...
# 18    9.10.274.8345   11.0  [{'participantId': 1, 'player': {'platformId':...
# 19    9.10.274.8345   11.0  [{'participantId': 1, 'player': {'platformId':...
# 20    9.10.274.8345   11.0  [{'participantId': 1, 'player': {'platformId':...
# 21    9.10.274.8345   11.0  [{'participantId': 1, 'player': {'platformId':...
# 22    9.10.274.8345   11.0  [{'participantId': 1, 'player': {'platformId':...
# 23    9.10.274.8345   11.0  [{'participantId': 1, 'player': {'platformId':...
# 24    9.10.274.8345   11.0  [{'participantId': 1, 'player': {'platformId':...
# 25    9.10.274.8345   12.0  [{'participantId': 1, 'player': {'platformId':...
# 26    9.10.274.8345   12.0  [{'participantId': 1, 'player': {'platformId':...
# 27    9.10.274.8345   11.0  [{'participantId': 1, 'player': {'platformId':...
# 28    9.10.274.8345   11.0  [{'participantId': 1, 'player': {'platformId':...
# 29    9.10.274.8345   11.0  [{'participantId': 1, 'player': {'platformId':...
# ...             ...    ...                                                ...
# 4020  9.10.274.8345   11.0  [{'participantId': 1, 'player': {'platformId':...
# 4021  9.10.274.8345   11.0  [{'participantId': 1, 'player': {'platformId':...
# 4022  9.10.274.8345   11.0  [{'participantId': 1, 'player': {'platformId':...
# 4023  9.10.274.8345   11.0  [{'participantId': 1, 'player': {'platformId':...
# 4024  9.10.274.8345   11.0  [{'participantId': 1, 'player': {'platformId':...
# 4025  9.10.274.8345   11.0  [{'participantId': 1, 'player': {'platformId':...
# 4026  9.10.274.8345   11.0  [{'participantId': 1, 'player': {'platformId':...
# 4027  9.10.274.8345   11.0  [{'participantId': 1, 'player': {'platformId':...
# 4028  9.10.274.8345   11.0  [{'participantId': 1, 'player': {'platformId':...
# 4029  9.10.274.8345   11.0  [{'participantId': 1, 'player': {'platformId':...
# 4030  9.10.274.8345   11.0  [{'participantId': 1, 'player': {'platformId':...
# 4031  9.10.274.8345   11.0  [{'participantId': 1, 'player': {'platformId':...
# 4032  9.10.274.8345   11.0  [{'participantId': 1, 'player': {'platformId':...
# 4033  9.10.274.8345   11.0  [{'participantId': 1, 'player': {'platformId':...
# 4034  9.10.274.8345   11.0  [{'participantId': 1, 'player': {'platformId':...
# 4035  9.10.274.8345   11.0  [{'participantId': 1, 'player': {'platformId':...
# 4036  9.10.273.9316   11.0  [{'participantId': 1, 'player': {'platformId':...
# 4037  9.10.273.9316   11.0  [{'participantId': 1, 'player': {'platformId':...
# 4038  9.10.273.9316   11.0  [{'participantId': 1, 'player': {'platformId':...
# 4039  9.10.273.9316   11.0  [{'participantId': 1, 'player': {'platformId':...
# 4040  9.10.273.9316   11.0  [{'participantId': 1, 'player': {'platformId':...
# 4041  9.10.273.9316   11.0  [{'participantId': 1, 'player': {'platformId':...
# 4042  9.10.273.9316   11.0  [{'participantId': 1, 'player': {'platformId':...
# 4043  9.10.273.9316   11.0  [{'participantId': 1, 'player': {'platformId':...
# 4044  9.10.273.9316   11.0  [{'participantId': 1, 'player': {'platformId':...
# 4045  9.10.273.9316   11.0  [{'participantId': 1, 'player': {'platformId':...
# 4046  9.10.274.8345   11.0  [{'participantId': 1, 'player': {'platformId':...
# 4047  9.10.274.8345   11.0  [{'participantId': 1, 'player': {'platformId':...
# 4048  9.10.274.8345   11.0  [{'participantId': 1, 'player': {'platformId':...
# 4049  9.10.274.8345   11.0  [{'participantId': 1, 'player': {'platformId':...
#
#                                            participants platformId  queueId  \
# 0     [{'participantId': 1, 'teamId': 100, 'champion...         KR    420.0
# 1     [{'participantId': 1, 'teamId': 100, 'champion...         KR    420.0
# 2     [{'participantId': 1, 'teamId': 100, 'champion...         KR    420.0
# 3     [{'participantId': 1, 'teamId': 100, 'champion...         KR    420.0
# 4     [{'participantId': 1, 'teamId': 100, 'champion...         KR    420.0
# 5     [{'participantId': 1, 'teamId': 100, 'champion...         KR    420.0
# 6     [{'participantId': 1, 'teamId': 100, 'champion...         KR    420.0
# 7     [{'participantId': 1, 'teamId': 100, 'champion...         KR    420.0
# 8     [{'participantId': 1, 'teamId': 100, 'champion...         KR    420.0
# 9     [{'participantId': 1, 'teamId': 100, 'champion...         KR    420.0
# 10    [{'participantId': 1, 'teamId': 100, 'champion...         KR    420.0
# 11    [{'participantId': 1, 'teamId': 100, 'champion...         KR    420.0
# 12    [{'participantId': 1, 'teamId': 100, 'champion...         KR    450.0
# 13    [{'participantId': 1, 'teamId': 100, 'champion...         KR    450.0
# 14    [{'participantId': 1, 'teamId': 100, 'champion...         KR    450.0
# 15    [{'participantId': 1, 'teamId': 100, 'champion...         KR    450.0
# 16    [{'participantId': 1, 'teamId': 100, 'champion...         KR    450.0
# 17    [{'participantId': 1, 'teamId': 100, 'champion...         KR    450.0
# 18    [{'participantId': 1, 'teamId': 100, 'champion...         KR    420.0
# 19    [{'participantId': 1, 'teamId': 100, 'champion...         KR    420.0
# 20    [{'participantId': 1, 'teamId': 100, 'champion...         KR    420.0
# 21    [{'participantId': 1, 'teamId': 100, 'champion...         KR    420.0
# 22    [{'participantId': 1, 'teamId': 100, 'champion...         KR    420.0
# 23    [{'participantId': 1, 'teamId': 100, 'champion...         KR    420.0
# 24    [{'participantId': 1, 'teamId': 100, 'champion...         KR    420.0
# 25    [{'participantId': 1, 'teamId': 100, 'champion...         KR    450.0
# 26    [{'participantId': 1, 'teamId': 100, 'champion...         KR    450.0
# 27    [{'participantId': 1, 'teamId': 100, 'champion...         KR    430.0
# 28    [{'participantId': 1, 'teamId': 100, 'champion...         KR    430.0
# 29    [{'participantId': 1, 'teamId': 100, 'champion...         KR    430.0
# ...                                                 ...        ...      ...
# 4020  [{'participantId': 1, 'teamId': 100, 'champion...         KR    420.0
# 4021  [{'participantId': 1, 'teamId': 100, 'champion...         KR    420.0
# 4022  [{'participantId': 1, 'teamId': 100, 'champion...         KR    420.0
# 4023  [{'participantId': 1, 'teamId': 100, 'champion...         KR    420.0
# 4024  [{'participantId': 1, 'teamId': 100, 'champion...         KR    420.0
# 4025  [{'participantId': 1, 'teamId': 100, 'champion...         KR    420.0
# 4026  [{'participantId': 1, 'teamId': 100, 'champion...         KR    420.0
# 4027  [{'participantId': 1, 'teamId': 100, 'champion...         KR    420.0
# 4028  [{'participantId': 1, 'teamId': 100, 'champion...         KR    420.0
# 4029  [{'participantId': 1, 'teamId': 100, 'champion...         KR    420.0
# 4030  [{'participantId': 1, 'teamId': 100, 'champion...         KR    420.0
# 4031  [{'participantId': 1, 'teamId': 100, 'champion...         KR    420.0
# 4032  [{'participantId': 1, 'teamId': 100, 'champion...         KR    420.0
# 4033  [{'participantId': 1, 'teamId': 100, 'champion...         KR    420.0
# 4034  [{'participantId': 1, 'teamId': 100, 'champion...         KR    420.0
# 4035  [{'participantId': 1, 'teamId': 100, 'champion...         KR    420.0
# 4036  [{'participantId': 1, 'teamId': 100, 'champion...         KR    420.0
# 4037  [{'participantId': 1, 'teamId': 100, 'champion...         KR    420.0
# 4038  [{'participantId': 1, 'teamId': 100, 'champion...         KR    420.0
# 4039  [{'participantId': 1, 'teamId': 100, 'champion...         KR    420.0
# 4040  [{'participantId': 1, 'teamId': 100, 'champion...         KR    420.0
# 4041  [{'participantId': 1, 'teamId': 100, 'champion...         KR    420.0
# 4042  [{'participantId': 1, 'teamId': 100, 'champion...         KR    420.0
# 4043  [{'participantId': 1, 'teamId': 100, 'champion...         KR    420.0
# 4044  [{'participantId': 1, 'teamId': 100, 'champion...         KR    420.0
# 4045  [{'participantId': 1, 'teamId': 100, 'champion...         KR    420.0
# 4046  [{'participantId': 1, 'teamId': 100, 'champion...         KR    420.0
# 4047  [{'participantId': 1, 'teamId': 100, 'champion...         KR    420.0
# 4048  [{'participantId': 1, 'teamId': 100, 'champion...         KR    420.0
# 4049  [{'participantId': 1, 'teamId': 100, 'champion...         KR    420.0
#
#       seasonId status                                              teams
# 0         13.0    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 1         13.0    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': T...
# 2         13.0    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': F...
# 3         13.0    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': T...
# 4         13.0    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 5         13.0    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 6         13.0    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': T...
# 7         13.0    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 8         13.0    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 9         13.0    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 10        13.0    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 11        13.0    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': F...
# 12        13.0    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': T...
# 13        13.0    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': F...
# 14        13.0    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 15        13.0    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': T...
# 16        13.0    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 17        13.0    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': T...
# 18        13.0    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 19        13.0    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 20        13.0    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 21        13.0    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 22        13.0    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 23        13.0    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 24        13.0    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 25        13.0    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 26        13.0    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 27        13.0    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': T...
# 28        13.0    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': T...
# 29        13.0    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': F...
# ...        ...    ...                                                ...
# 4020      13.0    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 4021      13.0    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': T...
# 4022      13.0    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': F...
# 4023      13.0    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': T...
# 4024      13.0    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 4025      13.0    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': T...
# 4026      13.0    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 4027      13.0    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': T...
# 4028      13.0    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': T...
# 4029      13.0    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 4030      13.0    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': F...
# 4031      13.0    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': T...
# 4032      13.0    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': F...
# 4033      13.0    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 4034      13.0    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 4035      13.0    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 4036      13.0    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 4037      13.0    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 4038      13.0    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': T...
# 4039      13.0    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 4040      13.0    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 4041      13.0    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': T...
# 4042      13.0    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': F...
# 4043      13.0    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 4044      13.0    NaN  [{'teamId': 100, 'win': 'Win', 'firstBlood': T...
# 4045      13.0    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 4046      13.0    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 4047      13.0    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 4048      13.0    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 4049      13.0    NaN  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
#
# [4050 rows x 14 columns]

# %% [markdown]
# # 팀 데이터로 데이터 화

# %%
with open('롤17500개.pickle','rb') as f:
    data = pickle.load(f)

# %%
data.index = range(len(data))

# %%
#챔피언아이디를 제외하고 딕셔너리를 뽑는다
a_ls = list(data['teams'])

# %% [markdown]
# #### team1

# %%
team1_df = pd.DataFrame()
for i in range(len(a_ls)):
    try:
        a_ls[i][0].pop('bans',None)
        team1 = pd.DataFrame(list(a_ls[i][0].values()),index = list(a_ls[i][0].keys())).T
        team1_df = team1_df.append(team1)
    except:
        pass
    
team1_df.index = range(len(team1_df))

# %%
len(team1_df)
# Out:
# 17484

# %% [markdown]
# #### team2

# %%
team2_df = pd.DataFrame()
for i in range(len(a_ls)):
    try:
        a_ls[i][1].pop('bans',None)
        team2 = pd.DataFrame(list(a_ls[i][1].values()),index = list(a_ls[i][1].keys())).T
        team2_df = team2_df.append(team2)
    except:
        pass
    
team2_df.index = range(len(team2_df))
# Out:
# C:\Users\tlsal\Anaconda3\lib\site-packages\pandas\core\frame.py:6201: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
#
#   sort=sort)

# %%
len(team2_df)
# Out:
# 17484

# %% [markdown]
# #### duration

# %%
data[['gameDuration']]
# Out:
#      gameDuration
# 0            1274
# 1            1720
# 2            2029
# 3             917
# 4            1228
# 5            1461
# 6             872
# 7             924
# 8            1997
# 9            1295
# 10           1695
# 11           1856
# 12           1058
# 13           1357
# 14           1116
# 15           1191
# 16            803
# 17           1176
# 18           1842
# 19            979
# 22           1242
# 23           1868
# 24           1741
# 27           1126
# 28            742
# 29           1338
# 30           2467
# 31           1266
# 32           1225
# 33            919
# ...           ...
# 1920         1212
# 1921          896
# 1922         1660
# 1923         1732
# 1924         1582
# 1925          861
# 1926         1618
# 1927         1722
# 1928         1151
# 1929         1226
# 1930         1755
# 1931          965
# 1932         1564
# 1933          194
# 1934         1177
# 1935         1167
# 1936         1224
# 1937         1312
# 1938         1256
# 1939         1547
# 1940         1570
# 1941         1396
# 1942         1622
# 1943          914
# 1944         1537
# 1945         1575
# 1946         2077
# 1947          716
# 1948         1381
# 1949          942
#
# [4042 rows x 1 columns]

# %% [markdown]
# # 최종 team데이터

# %%
data_team = pd.concat([team1_df,team2_df,data[['gameDuration']]],axis=1)

# %%
data_team2 = pd.concat([team1_df,data[['gameDuration']]],axis=1) #분석을 위해서 상대편데이터는 일단 빼고

# %%
with open('team_data.pickle','wb') as f:
    pickle.dump(data_team,f,pickle.HIGHEST_PROTOCOL)

# %%
with open('team_data2.pickle','wb') as f:
    pickle.dump(data_team2,f,pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ### 분석을 위한 데이터셋

# %%
df_team = pd.read_pickle('team_data2.pickle')

# %% [markdown]
# # parcitipants 데이터 화

# %% [markdown]
# #### 각 소환사별 정보 데이터

# %%
need = list(data['participants'].iloc[0][8]['stats'].keys())

# %%
matchers = ['assists','deaths','goldEarned','item','kills','minionKilled','totalDamageDealt','totalDamageDealtToChampions','totalDamageTaken','totalHeal','totalTimeCrowdControlDealt','wardsPlaced']

# %%
size = [s for s in need if any(xs in s for xs in matchers)]

# %%
'item' in size[0]
# Out:
# True

# %%
part_ls = []
part2_ls = []
item0 = []
for i in range(len(size)):
    if 'item' in size[i]:
        item0.append(size[i])
    else:
        part_ls.append(size[i])

# %%
part_ls2 = [item0] + part_ls

# %%
part2_ls = []
item1 = []
for i in range(len(size)):
    if 'item' in size[i]:
        item1.append(data['participants'].iloc[0][8]['stats'][size[i]])
    else:
        part2_ls.append(data['participants'].iloc[0][8]['stats'][size[i]])

# %%
part2_ls2 = [item1] + part2_ls

# %% [markdown]
# ### 소환사아이디코드 / 챔피언코드

# %%
list_part_champ_columns = [ 'championId_'+ str(i) for i in range(10)]
list_part_summoner_columns = [ 'summonerId_'+ str(i) for i in range(10)]

# %%
data['participantIdentities'].iloc[0][2]['player']['summonerName']
# Out:
# '루즈한 라인전'

# %%
champ1 = []
for i in range(len(data)):
    champ0 = []
    for j in range(len(data['participants'].iloc[i])):
        champ0.append(data['participants'].iloc[i][j]['championId'])
        
    champ1.append(champ0)

# %%
summor1 = []
summor2 = []
for i in range(len(data)):
    summor0 = []
    summor00 = []
    for j in range(len(data['participantIdentities'].iloc[i])):
        summor0.append(data['participantIdentities'].iloc[i][j]['player']['summonerId'])
        summor00.append(data['participantIdentities'].iloc[i][j]['player']['summonerName'])
        
    summor1.append(summor0)
    summor2.append(summor00)

# %%
champ_df = pd.DataFrame(champ1,columns = list_part_champ_columns)

# %%
sohwan1_df = pd.DataFrame(summor1,columns = list_part_summoner_columns)

# %%
sohwan2_df = pd.DataFrame(summor2,columns = list_part_summoner_columns)

# %%
part_df = pd.concat([champ_df,sohwan1_df],axis=1)

# %%
with open('participants.pickle','wb') as f:
    pickle.dump(part_df,f,pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# # 챔피언 정보 불러오기

# %%
with urllib.request.urlopen('http://ddragon.leagueoflegends.com/cdn/6.24.1/data/en_US/champion.json') as response:
    champion_info = json.loads(response.read().decode('utf8'))

# %%
data_champion_info = champion_info['data']

# %%
list_stats_columns = list(data_champion_info['Ryze']['stats'].keys())
list_info_columns = list(data_champion_info['Ryze']['info'].keys())

# %%
df_champion_key = pd.DataFrame({
    "key":[float(value['key']) for key, value in data_champion_info.items()]
})

# %%
#key데이터 생성
df_champion_info = pd.DataFrame()
start_time = time.time()
for j in range(len(data_champion_info)):
    s7 = pd.Series([list(value['info'].values()) for key, value in data_champion_info.items()][j], index=list_info_columns)
    df_champion_info = df_champion_info.append(s7, ignore_index=True)

# %%
# stats 데이터 프레임 만들기
df_champion_stats = pd.DataFrame()
start_time = time.time()
for j in range(len(data_champion_info)):
    s6 = pd.Series([list(value['stats'].values()) for key, value in data_champion_info.items()][j], index=list_stats_columns)
    df_champion_stats = df_champion_stats.append(s6, ignore_index=True)
# Out:
# 18.125519037246704s
# 0.30817484855651855s

# %%
df_champions = pd.concat([df_champion_key, df_champion_info, df_champion_stats], axis=1)

# %%
with open('챔피언정보.pickle','wb') as f:
    pickle.dump(df_champions,f,pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# # 분석 시작
# A팀의 데이터로만 분석
# 예측하려는 종속 변수인 승/패는 대칭적인 변수임

# %%
df_team.head()
# Out:
#   teamId   win firstBlood firstTower firstInhibitor firstBaron firstDragon  \
# 0    100  Fail       True      False          False      False       False
# 1    100   Win       True       True           True       True        True
# 2    100   Win      False      False           True       True       False
# 3    100   Win       True       True           True      False        True
# 4    100  Fail      False      False          False      False       False
#
#   firstRiftHerald towerKills inhibitorKills baronKills dragonKills  \
# 0           False          2              0          0           0
# 1            True         10              2          1           4
# 2           False         11              5          1           1
# 3            True          5              1          0           1
# 4           False          0              0          0           0
#
#   vilemawKills riftHeraldKills dominionVictoryScore gameDuration
# 0            0               0                    0         1274
# 1            0               1                    0         1720
# 2            0               0                    0         2029
# 3            0               1                    0          917
# 4            0               0                    0         1228

# %%
data_team2 = df_team.dropna(axis=0)

# %%
data_team2 = data_team2[list(data_team2.columns)[2:]]

# %% [markdown]
# #### 모델링을 위한 라벨링

# %%
from sklearn.preprocessing import LabelEncoder
for i in range(0,6):
    le = LabelEncoder()
    y = list(data_team2.iloc[:,i])
    
    le.fit(y)
    y2 = le.transform(y) 
    
    data_team2.iloc[:,i] = y2

# %%
le.inverse_transform(y2) #디코더

# %% [markdown]
# #### dictionary와 map함수를 이용한 라벨링

# %%
dict_winner = {False : 0, True: 1}

# %%
data_team2['firstBlood'] = data_team2['firstBlood'].map(dict_winner)
# Out:
# C:\Users\tlsal\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
data_team2['firstTower'] = data_team2['firstTower'].map(dict_winner)
# Out:
# C:\Users\tlsal\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
data_team2['firstInhibitor'] = data_team2['firstInhibitor'].map(dict_winner)
# Out:
# C:\Users\tlsal\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
data_team2['firstBaron'] = data_team2['firstBaron'].map(dict_winner)
# Out:
# C:\Users\tlsal\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
data_team2['firstDragon'] = data_team2['firstDragon'].map(dict_winner)
# Out:
# C:\Users\tlsal\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
data_team2['firstRiftHerald'] = data_team2['firstRiftHerald'].map(dict_winner)
# Out:
# C:\Users\tlsal\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
dict_winner2 = {"Win" : 0, "Fail": 1}

# %% [markdown]
# ### RF

# %%
data_team = df_team.dropna(axis=0)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data_team2, np.array(data_team['win'].map(dict_winner2).tolist()), test_size=0.25, stratify=np.array(data_team['win'].map(dict_winner2).tolist()), random_state=123456)

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(n_estimators=100, oob_score=True, random_state=123456)
rf.fit(X_train, y_train) #소환사 코드를 float로 바꿔줘야함 일단 team으로 예측해볼까?
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=1,
#             oob_score=True, random_state=123456, verbose=0,
#             warm_start=False)

# %%
#데이터를 더 수집했더니 정확도가 하락했네
from sklearn.metrics import accuracy_score

predicted = rf.predict(X_test)
accuracy = accuracy_score(y_test, predicted)

print(f'Out-of-bag score estimate: {rf.oob_score_:.3}')
print(f'Mean accuracy score: {accuracy:.3}')
# Out:
# Out-of-bag score estimate: 0.866
# Mean accuracy score: 0.869

# %%
clf_rf = RandomForestClassifier()

# %%
clf_rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
y_pred = clf_rf.predict(X_test)

# %%
print("테스트 정확도: {}".format(accuracy_score(y_test, y_pred)) )
# Out:
# 테스트 정확도: 0.8701625830089306

# %% [markdown]
# ### GBC(Gradient Boosting classifier)

# %% [markdown]
# overfitting를 막기 위한 boosting기반 학습
# 1. 학습량을 늘린다
# 2. 학습률을 낮춘다
# 3. 트리의 깊이를(max_depth)낮춰 pre-pruning을 강하게 한다.
# 이와 같은 방법으로 학습 시키는 것은 모델의 복잡도를 감소시키므로 train 세트의 정확도를 낮출 수 있다.

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
clf_gbc = GradientBoostingClassifier()

# %%
clf_gbc.fit(X_train,y_train)
# Out:
# GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=100,
#               presort='auto', random_state=None, subsample=1.0, verbose=0,
#               warm_start=False)

# %%
y_pred = clf_gbc.predict(X_test)

# %%
print('정확도 = ' + str(accuracy_score(y_test,y_pred)))
# Out:
# 정확도 = 0.881154110373

# %% [markdown]
# # xgboost

# %%
from xgboost import XGBClassifier
import xgboost as xgb
from xgboost import plot_importance
from matplotlib import pyplot

# %%
xgb_model.fit(X_train,y_train)
#booster: 어떤 부스터 구조를 쓸지 결정한다. 이것은 gbtree, gblinear, dart가 있다.
#nthread: 몇 개의 쓰레드를 동시에 처리하도록 할지 결정한다. 디폴트는 “가능한 한 많이”.
#num_feature: feature 차원의 숫자를 정해야 하는 경우 옵션을 세팅한다. 디폴트는 “가능한 한 많이.”
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bynode=1, colsample_bytree=1, gamma=0, learning_rate=0.1,
#        max_delta_step=0, max_depth=3, min_child_weight=1, missing=None,
#        n_estimators=100, n_jobs=1, nthread=None,
#        objective='binary:logistic', random_state=0, reg_alpha=0,
#        reg_lambda=1, scale_pos_weight=1, seed=None, silent=None,
#        subsample=1, verbosity=1)

# %%
#xgb로 학습시키기 위해서는 dtypes이 단순하게 int형식이면 안된다. 따라서 데이터 형식을 float로 변환시켜줘야함
X_train[['towerKills', 'inhibitorKills', 'baronKills', 'dragonKills', 'vilemawKills', 'riftHeraldKills', 'dominionVictoryScore', 'gameDuration']] = X_train[['towerKills', 'inhibitorKills', 'baronKills', 'dragonKills', 'vilemawKills', 'riftHeraldKills', 'dominionVictoryScore', 'gameDuration']].astype('float')

#xgb로 학습시키기 위해서는 dtypes이 단순하게 int형식이면 안된다. 따라서 데이터 형식을 float로 변환시켜줘야함
X_test[['towerKills', 'inhibitorKills', 'baronKills', 'dragonKills', 'vilemawKills', 'riftHeraldKills', 'dominionVictoryScore', 'gameDuration']] = X_test[['towerKills', 'inhibitorKills', 'baronKills', 'dragonKills', 'vilemawKills', 'riftHeraldKills', 'dominionVictoryScore', 'gameDuration']].astype('float')

xgb_model = XGBClassifier()
xgb_model.fit(X_train,y_train)
y_pred = xgb_model.predict(X_test)

print('테스트 정확도 = ' + str(accuracy_score(y_test,y_pred)))#정확도 계산
# Out:
# C:\Users\tlsal\Anaconda3\lib\site-packages\pandas\core\frame.py:2540: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[k1] = value[k2]
# 테스트 정확도 = 0.883215021754

# %% [markdown]
# #### xgboosting 알고리즘 변수중요도

# %%
plot_importance(xgb_model)
pyplot.show()

# %% [markdown]
# ## Light GBM
# https://setscholars.net/2019/02/16/how-to-classify-wine-using-different-boosting-ensemble-models-e-g-xgboost-catboost-lightgbm-multiclass-classification-in-python/

# %%
from lightgbm import plot_importance

# %%
import lightgbm as lgb
from lightgbm import LGBMClassifier
from sklearn import metrics

# %%
#xgb로 학습시키기 위해서는 dtypes이 단순하게 int형식이면 안된다. 따라서 데이터 형식을 float로 변환시켜줘야함
X_train[['towerKills', 'inhibitorKills', 'baronKills', 'dragonKills', 'vilemawKills', 'riftHeraldKills', 'dominionVictoryScore', 'gameDuration']] = X_train[['towerKills', 'inhibitorKills', 'baronKills', 'dragonKills', 'vilemawKills', 'riftHeraldKills', 'dominionVictoryScore', 'gameDuration']].astype('float')

#xgb로 학습시키기 위해서는 dtypes이 단순하게 int형식이면 안된다. 따라서 데이터 형식을 float로 변환시켜줘야함
X_test[['towerKills', 'inhibitorKills', 'baronKills', 'dragonKills', 'vilemawKills', 'riftHeraldKills', 'dominionVictoryScore', 'gameDuration']] = X_test[['towerKills', 'inhibitorKills', 'baronKills', 'dragonKills', 'vilemawKills', 'riftHeraldKills', 'dominionVictoryScore', 'gameDuration']].astype('float')
# Out:
# C:\Users\tlsal\Anaconda3\lib\site-packages\pandas\core\frame.py:2540: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[k1] = value[k2]

# %%
model = LGBMClassifier()

# %%
model.fit(X_train, y_train)
# Out:
# LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#         n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#         random_state=None, reg_alpha=0.0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0)

# %%
y_pred = model.predict(X_test)

print('테스트 정확도 = ' + str(accuracy_score(y_test,y_pred)))#정확도 계산
# Out:
# 테스트 정확도 = 0.884817952828

# %%
#혼돈행렬을 통한 정확도 산정
metrics.confusion_matrix(y_test, y_pred)
# Out:
# array([[1907,  259],
#        [ 244, 1957]], dtype=int64)

# %%
plot_importance(model) #모델의 변수중요도

# %% [markdown]
# ## light gbm 회귀예측

# %%
import lightgbm as ltb

# %% [markdown]
# # 분류문제 voting ensemble

# %%
from sklearn.ensemble import VotingClassifier

# %%
votingC = VotingClassifier(estimators=[('gbc', gbc),('xgb', xgb),('lgb',lgb)], voting='soft')

# %%
pred3 = votingC.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-86-601fa6cd751d> in <module>()
# ----> 1 pred3 = votingC.fit(X_train, y_train)
#
# ~\Anaconda3\lib\site-packages\sklearn\ensemble\voting_classifier.py in fit(self, X, y, sample_weight)
#     187                 delayed(_parallel_fit_estimator)(clone(clf), X, transformed_y,
#     188                                                  sample_weight=sample_weight)
# --> 189                 for clf in clfs if clf is not None)
#     190
#     191         return self
#
# ~\Anaconda3\lib\site-packages\sklearn\externals\joblib\parallel.py in __call__(self, iterable)
#     777             # was dispatched. In particular this covers the edge
#     778             # case of Parallel used with an exhausted iterator.
# --> 779             while self.dispatch_one_batch(iterator):
#     780                 self._iterating = True
#     781             else:
#
# ~\Anaconda3\lib\site-packages\sklearn\externals\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     618
#     619         with self._lock:
# --> 620             tasks = BatchedCalls(itertools.islice(iterator, batch_size))
#     621             if len(tasks) == 0:
#     622                 # No more tasks available in the iterator: tell caller to stop.
#
# ~\Anaconda3\lib\site-packages\sklearn\externals\joblib\parallel.py in __init__(self, iterator_slice)
#     125
#     126     def __init__(self, iterator_slice):
# --> 127         self.items = list(iterator_slice)
#     128         self._size = len(self.items)
#     129
#
# ~\Anaconda3\lib\site-packages\sklearn\ensemble\voting_classifier.py in <genexpr>(.0)
#     187                 delayed(_parallel_fit_estimator)(clone(clf), X, transformed_y,
#     188                                                  sample_weight=sample_weight)
# --> 189                 for clf in clfs if clf is not None)
#     190
#     191         return self
#
# ~\Anaconda3\lib\site-packages\sklearn\base.py in clone(estimator, safe)
#      56                             "it does not seem to be a scikit-learn estimator "
#      57                             "as it does not implement a 'get_params' methods."
# ---> 58                             % (repr(estimator), type(estimator)))
#      59     klass = estimator.__class__
#      60     new_object_params = estimator.get_params(deep=False)
#
# TypeError: Cannot clone object '<module 'xgboost' from 'C:\\Users\\tlsal\\Anaconda3\\lib\\site-packages\\xgboost\\__init__.py'>' (type <class 'module'>): it does not seem to be a scikit-learn estimator as it does not implement a 'get_params' methods.

# %% [markdown]
# # 모델의 변수 중요도 시각화
# https://woolulu.tistory.com/22?category=778360

# %% [markdown]
# #### 부스팅기반 알고리즘의 변수 중요도 - gradientboosting classfier

# %%
gbc = GradientBoostingClassifier(max_depth=1, random_state=0)

gbc.fit(X_train, y_train)
# Out:
# GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=1,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=100,
#               presort='auto', random_state=0, subsample=1.0, verbose=0,
#               warm_start=False)

# %%
n_feature = data_team2.shape[1]

index=np.arange(n_feature)

# %%
plt.barh(index, gbc.feature_importances_, align='center')

plt.yticks(index, list(data_team2.columns))

plt.xlabel('feature importances', size=15)

plt.ylabel('feature', size=15)

plt.show()

# %% [markdown]
# #### 배깅, 트리기반 알고리즘 변수중요도

# %%
clf_rf = RandomForestClassifier(max_depth=1,random_state=0)
clf_rf.fit(X_train, y_train)
n_feature = data_team2.shape[1]

index=np.arange(n_feature)

# %%
plt.barh(index, clf_rf.feature_importances_, align='center')

plt.yticks(index, list(data_team2.columns))

plt.xlabel('feature importances', size=15)

plt.ylabel('feature', size=15)

plt.show()

# %%
#일단 변수중요도로 나온 컬럼의 갯수와 기존의 데이터와 컬럼갯수가 같음

# %%
#만약 변수중요도로 만든 데이터프레임이 df1 / 기존의 데이터프레임은 df2
for i in range(len(list(df1.columns))):
    if df1['변수중요도'].iloc[i] == 0:
        df2 = df2.drop(list(df2.columns)[i],axis=1)#list(data_team2.columns)[i]->컬럼명임
    else:
        pass

# %% [markdown]
# ### participants 데이터로 예측하기 하지만 소환사id가 유니코드화되어있어서 다른 방법 강구

# %%
team_df['win'] = data_team['win'].map(dict_winner)

# %%
np.array(data_team['win'].map(dict_winner).tolist())
# Out:
# array([1, 0, 0, ..., 1, 1, 1])

# %%
dict_winner = {"Win" : 0, "Fail": 1}

# %%
 # 학습 클래스 데이터
dict_winner = { 0: '200', 1: '100'}
y_train  = data_team['win'].map(dict_winner)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-205-9f06a4783221> in <module>()
#       1 # 학습 클래스 데이터
#       2 dict_winner = { 0: '200', 1: '100'}
# ----> 3 y_train  = data_team['win'].map(dict_winner)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4370             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4371                 return self[name]
# -> 4372             return object.__getattribute__(self, name)
#    4373
#    4374     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'map'

# %%
part_df[list(part_df.columns)[:-1]]
# Out:
#       championId_0  championId_1  championId_2  championId_3  championId_4  \
# 0               24            22           412           421            55
# 1               67            58           142            64           555
# 2               44            11           164            15            25
# 3               98            68             5            43            67
# 4               98            30           266            12            81
# 5              240           126            15            19            99
# 6              126           111           145           120           266
# 7              412           164             7           236            13
# 8              113             3            21           517            39
# 9              203            68           266            81           412
# 10             126             4             9            81             2
# 11               9            81            64           114           163
# 12             412            84            76           266            90
# 13              57            40           107            99           103
# 14              43             6           127           202             4
# 15             136           163           266            74            16
# 16              39            43           236            75           111
# 17             517            48            37            17            25
# 18              81           517           141            84             9
# 19             266           163           555             2            15
# 20             350             2            58             7           145
# 21              30            81           555           517           150
# 22             145           111           141            13            91
# 23              13            30            37           145           154
# 24              38            54            39           350            25
# 25              15           107            60           268            59
# 26              75            33            39           350            18
# 27             350           266           203           145            55
# 28             266            55            51            99            41
# 29              18            58           202           101            96
# ...            ...           ...           ...           ...           ...
# 4012           111            64           498            39            13
# 4013           267           236            51            60            13
# 4014           266            61           163            37             3
# 4015           164           517            44            81             8
# 4016            24           497           421             8           498
6OHmFtvfycjnRPQpwy1goVQHJ9hJgsljSNtcGXFTxc-GMCw
# 4023  lCAPMvVutF4Hd06uKbWZqX_YlpIjH5rKYQhP7SV90rwFLZQ
# 4024  elL22XjJn_ncfJs1lcYn1xQ9xx_f1B5Y06rcO4rZQV7ZmIQ
# 4025   PoEhtcs3SU66KItElrmOu0CzI82q4Fc1yScsAdf2gf2_aA
# 4026  7Ga5rVaajMTa2-WRGrz5pwiBbOh27QZGAUiSi-7T2Ny609E
# 4027  xNrzFq1qqh2LDO3vJF11JmapK5VoJOSSAKDrpZTFaBYUY-Q
# 4028  iIkBIGKUdsNkWVZ4naJKcnLCJDqSIzxtCKAMgHXP7NIFHlk
# 4029  5durDoIDFlP0bK8PUYdsp-EfHeTBrLIStlg9nSTMqY4sevY
# 4030  6OHmFtvfycjnRPQpwy1goVQHJ9hJgsljSNtcGXFTxc-GMCw
# 4031  xaqb4s7JEqAeMLQkZ1Yxw5OnZ9Nqbx4duuErRZwQVW2AHvc
# 4032  UBzo8XzuJ5DIdnyRfJNPmzf4enlfNvBU15ZIDBdXEykGCh8
# 4033   b6sjZClTMKGHx35IUXqHFY0QdewlpR5TyqDfo_0-66oisA
# 4034  D7Z2TrKO_u-3-8IPdPZg3MWa4GS9V9lSrDBxblSk3X5imZA
# 4035  ybZoNdqUCLV8FJjWpExOrBUTu2KbU4-1BzKhUvKUyBo-GRU
# 4036  gVckaHIMk73PfmAwaruV69-iLaeqBkp6ETBjihoKgm1hHFg
# 4037  6OHmFtvfycjnRPQpwy1goVQHJ9hJgsljSNtcGXFTxc-GMCw
# 4038  VFDeeiuBg1EQn37k23zI0zMqfUuzYoVbf8y5f4ffJOLOY1w
# 4039   k01YrTVXNVKnE7GZjxfqhomsQxQNlD5ISf3VrWMiNFTXhw
# 4040   qvq9V6ZlwujH3GfjFJ0Etz8jvdLsGdw3h5Jfuy_4kp0jYA
# 4041  n0ECLK88eQX8igKlVovgSgLa9rjFtsrCsHUPXs_ZmRTVrIo
#
# [4042 rows x 20 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(part_df[list(part_df.columns)[:-1]], np.array(data_team['win'].map(dict_winner).tolist()), test_size=0.25, stratify=np.array(data_team['win'].map(dict_winner).tolist()), random_state=123456)

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(n_estimators=100, oob_score=True, random_state=123456)
rf.fit(X_train, y_train) #소환사 코드를 float로 바꿔줘야함 일단 team으로 예측해볼까?
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-261-8735c073059c> in <module>()
#       2
#       3 rf = RandomForestClassifier(n_estimators=100, oob_score=True, random_state=123456)
# ----> 4 rf.fit(X_train, y_train)
#
# ~\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py in fit(self, X, y, sample_weight)
#     245         """
#     246         # Validate or convert input data
# --> 247         X = check_array(X, accept_sparse="csc", dtype=DTYPE)
#     248         y = check_array(y, accept_sparse='csc', ensure_2d=False, dtype=None)
#     249         if sample_weight is not None:
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     431                                       force_all_finite)
#     432     else:
# --> 433         array = np.array(array, dtype=dtype, order=order, copy=copy)
#     434
#     435         if ensure_2d:
#
# ValueError: could not convert string to float: 'fRZ6_Js4AiSURt-_Cd_cPLbFIUT2a-UJKCjOC8pmgbJCZ48'

# %%
def search_result(request):
    if request.method == 'GET':
        summoner_name = request.GET.get('search_text') #GET방식으로 호출
        #request.args.get('name' = 'search_text') 이렇게 아이디를 입력받을 수 있음
        summoner_exist = False
        sum_result = {}
        solo_tier = {}
        team_tier = {}
        store_list = []
        game_list ={}
        game_list2 = []
        api_key = 'RGAPI-9a6c3b4d-e5c8-47fe-af40-5e6677db7f91'

        summoner_url = "https://kr.api.riotgames.com/lol/summoner/v4/summoners/by-name/" + str(summoner_name)    #소환사 정보 검색
        params = {'api_key': api_key} #api를 호출하는데 중요
        res = requests.get(summoner_url, params=params)#api키를 param으로만 받아도 데이터를 불러올 수 있음
        # summoners_result = json.loads(((res.text).encode('utf-8')))
        
        if res.status_code == requests.codes.ok:                #결과값이 정상적으로 반환되었을때만 실행하도록 설정
            summoner_exist = True
            summoners_result = res.json()                        #response 값을 json 형태로 변환시키는 함수
            if summoners_result:
                sum_result['name'] = summoners_result['name']
                sum_result['level'] = summoners_result['summonerLevel']
                sum_result['profileIconId'] = summoners_result['profileIconId']
                
                tier_url = "https://kr.api.riotgames.com/lol/league/v4/positions/by-summoner/" + summoners_result['id']    #소환사 티어 검색
                tier_info = requests.get(tier_url, params=params)
                tier_info = tier_info.json()
            
                if len(tier_info) == 1:            #자유랭크 또는 솔로랭크 둘중 하나만 있는경우
                    tier_info = tier_info.pop()
                    if tier_info['queueType'] == 'RANKED_FLEX_SR':        #자유랭크인 경우
                        team_tier['rank_type'] = '자유랭크 5:5'
                        team_tier['tier'] = tier_info['tier']
                        team_tier['rank'] = tier_info['rank']
                        team_tier['points'] = tier_info['leaguePoints']
                        team_tier['wins'] = tier_info['wins']
                        team_tier['losses'] = tier_info['losses']
                    else:                                                #솔로랭크인 경우
                        solo_tier['rank_type'] = '솔로랭크 5:5'
                        solo_tier['tier'] = tier_info['tier']
                        solo_tier['rank'] = tier_info['rank']
                        solo_tier['points'] = tier_info['leaguePoints']
                        solo_tier['wins'] = tier_info['wins']
                        solo_tier['losses'] = tier_info['losses']        
                
                if len(tier_info) == 2:            #자유랭크, 솔로랭크 둘다 전적이 있는경우
                    for item in tier_info:
                        store_list.append(item)
                    solo_tier['rank_type'] = '솔로랭크 5:5'
                    solo_tier['tier'] = store_list[0]['tier']
                    solo_tier['rank'] = store_list[0]['rank']
                    solo_tier['points'] = store_list[0]['leaguePoints']
                    solo_tier['wins'] = store_list[0]['wins']
                    solo_tier['losses'] = store_list[0]['losses']
                    
                    team_tier['rank_type'] = '자유랭크 5:5'
                    team_tier['tier'] = store_list[1]['tier']
                    team_tier['rank'] = store_list[1]['rank']
                    team_tier['points'] = store_list[1]['leaguePoints']
                    team_tier['wins'] = store_list[1]['wins']
                    team_tier['losses'] = store_list[1]['losses']
            
        return render (request, 'score/search_result.html', {'summoner_exist': summoner_exist, 'summoners_result': sum_result, 'solo_tier': solo_tier, 'team_tier': team_tier})
